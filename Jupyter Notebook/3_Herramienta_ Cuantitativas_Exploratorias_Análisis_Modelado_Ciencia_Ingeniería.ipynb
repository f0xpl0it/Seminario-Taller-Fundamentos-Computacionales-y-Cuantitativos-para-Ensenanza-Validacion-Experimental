# %% [markdown]
# <table style="width: 100%;"> <tr> <td style="width: 60%; align: middle;"> <p style="font-size: 28px; color: #f25625; font-family: Arial; font-weight: bold;"> Enfoques Estadísticos Cuantitativos para la Validación Experimental<br> en Proyectos de Ciencia e Ingeniería </p> </td> <td style="width: 40%; text-align: center; vertical-align: middle;"> <img width="180" src="data:image/png;base64,..."> </td> </tr> </table>

# %% [markdown]
# <p style="text-align:right; font-weight:bold;">Autor: Carlos Julio Mayorga Arias Ph.D.</p>

# %% [markdown]
# # <center> Herramientas Cuantitativas Exploratorias para el Análisis y Modelado en Ciencia e Ingeniería

# %% [markdown]
# ## Contenido
#
# 1. [Introducción](#1)
#    1. [Repositorio](#1.1)
#    2. [Análisis Cuantitativo de Riesgos: Matriz de Probabilidad de Impacto](#1.2)
#       1. [Matriz 3x3: Estructura Típica](#1.2.1)
#       2. [Implementación en Python](#1.2.2)
#       3. [Interpretación Cuantitativa](#1.2.3)
#    3. [Clasificación de Datos: Aplicación de la Regla de Sturges](#1.3)
#       1. [Regla de Sturges: Definición](#1.3.1)
#       2. [Implementación en Python](#1.3.2)
#       3. [Interpretación Cuantitativa](#1.3.3)
#       4. [Comparación con otros métodos](#1.3.4)
#    4. [Diferencias entre el Análisis Cuantitativo y Cualitativo](#1.4)
#         1. [Comparación Conceptual](#1.4.1)
#         2. [Aplicación a la Matriz de Probabilidad de Impacto](#1.4.2)
#         3. [Aplicación a la Regla de Sturges](#1.4.3)
#         4. [Conexión entre ambos enfoques](#1.4.4)
#         5. [Conclusión](#1.4.5)
# 2. [Tipos de investigación cuantitativa](#2)
#    1. [Investigación Experimental](#2.1)
#    2. [Investigación Cuasi-experimental](#2.2)
#    3. [Investigación Cuantitativa No Experimental](#2.3)
# 3. [Ejemplos Prácticos](#3)
#       1. [Ejemplo 1: PCA (Análisis de Componentes Principales)](#3.1)
#       2. [Ejemplo 2: ANOVA + Tukey HSD](#3.2)
#       3. [Ejemplo 3: Aplicación en Ciencia e Ingeniería](#3.3)
# 4. [Aplicaciones Prácticas del Análisis Cuantitativo](#4)
#       1. [Ejemplo 1: Interpolación con Matriz de Vandermonde](#4.1)
#       2. [Ejemplo 2: Ajuste de Regresión Lineal Simple](#4.2)
#       3. [Ejemplo 3: Solución de una Ecuación Diferencial Ordinaria (EDO) con el Método de Euler](#4.3)
#       4. [Ejemplo 4: Modelo Logístico de Crecimiento Poblacional](#4.4)
#       5. [Ejemplo 5: Análisis de Componentes Principales (PCA)](#4.5)
# 5. [Ejercicios de Evaluación](#5)
#       1. [Ejercicio 1: Interpolación con Matriz de Vandermond](#5.1)
#       2. [Ejercicio 2: Solución de una Ecuación Diferencial con Método de Euler](#5.2)
#       3. [Ejercicio 3: Modelo Logístico de Crecimiento Poblacional](#5.3)
#       4. [Ejercicio 4:  PCA (dataset + análisis)](#5.4)
#       5. [Ejercicio 5: Simulación Cuántica de Qubits con QuTiP](#5.5)
#       5. [Criterios de Evaluación](#5.6)
#       6. [Informe en base a los códigos](#5.7)
#       7. [Cuaderno de Ejercicios](#5.8)
# 6. [Fundamentación y Cierre Epistemológico del Análisis Cuantitativo ](#6)
#       1. [Teorema 2.3 (Completo, de la página 32 de la tesis)](#6.1)
#       2. [Instrumentos del Día 1 y Día 2 en relación con el Teorema 2.3](#6.2)
#       3. [Clasificación de Malware con Integración de Métodos Cuantitativos, Incluyendo EDR](#6.3)
# 7. [Referencias](#7)

# %% [markdown]
# <a id="1"></a>
# # 1. Introducción

# %% [markdown]
# El análisis cuantitativo en ciencia e ingeniería no se limita únicamente a técnicas estadísticas avanzadas, sino que comienza con herramientas exploratorias y de modelado matemático que permiten comprender, visualizar y simular datos de manera precisa.

# %% [markdown]
# Se abordarán herramientas fundamentales que permiten:
# * Evaluar riesgos e incertidumbre (Matriz de Impacto)
# * Clasificar y representar datos (Sturges)
# * Explorar relaciones y estructuras internas (PCA)
# * Simular dinámicas (Euler, modelo logístico)
# * Interpolar o reconstruir funciones (Matriz de Vandermonde)
#
# Este conjunto de herramientas constituye el núcleo del enfoque cuantitativo aplicado a proyectos reales.

# %% [markdown]
# <a id="1.1"></a>
# ## 1.1. Repositorio

# %% [markdown]
# <table width="100%" style="background-color: transparent; text-align:left;">
#     <tr style="background-color: transparent; text-align:left;">
#         <td width="700" style="font-size: 16px; text-align:left;">
#             El notebook de la presentación, ejemplos y ejercicios se encuentran disponibles en el siguiente repositorio:
#             <br><br>
#             <pre>https://github.com/Zexc4/Seminario-Taller-Buenas-practicas-en-la-Investigacion-Cuantitativa/tree/main</pre>
#         </td>
#                 <td><img style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,..."></td>
#     </tr>
# </table>

# %% [markdown]
# <a id="1.2"></a>
# ## 1.2. Análisis Cuantitativo de Riesgos: Matriz de Probabilidad de Impacto

# %% [markdown]
# La Matriz de Probabilidad de Impacto es una técnica clásica de evaluación de riesgos utilizada para representar de forma cuantitativa eventos inciertos que puedan afectar un proyecto experimental, una simulación o un sistema.

# %% [markdown]
# Esta matriz se construye combinando dos dimensiones:
#
# * Probabilidad de ocurrencia del evento (Baja, Media, Alta)
# * Impacto si el evento ocurre (Leve, Moderado, Crítico)
#
# Cada combinación genera un valor numérico, permitiendo calcular un nivel de riesgo para priorizar acciones.

# %% [markdown]
# <a id="1.2.1"></a>
# ### 1.2.1. Matriz 3x3: Estructura Típica

# %% [markdown]
# | Probabilidad / Impacto | Leve (1) | Moderado (2) | Crítico (3) |
# | ---------------------- | -------- | ------------ | ----------- |
# | **Baja (1)**           | 1        | 2            | 3           |
# | **Media (2)**          | 2        | 4            | 6           |
# | **Alta (3)**           | 3        | 6            | 9           |

# %% [markdown]
# > Valores más altos indican mayor prioridad de mitigación.

# %% [markdown]
# <a id="1.2.2"></a>
# ### 1.2.2. Implementación en Python

# %% [markdown]
# > La plataforma [PreventionWeb](https://www.preventionweb.net/understanding-disaster-risk/disaster-losses-and-statistics/global-risk-data-sets), vinculada a iniciativas como INFORM y GIRI, ofrece datos sobre riesgos globales en infraestructura, desastres naturales, inundaciones, terremotos, entre otros. Estos datos están en formato abierto y son ampliamente utilizados en estudios científicos sobre gestión de riesgos y resiliencia

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Simulación de dataset basado en datos reales (gestión de riesgos)
df = pd.DataFrame({
    'Evento': ['Terremoto Menor', 'Terremoto Moderado', 'Terremoto Mayor'],
    'Probabilidad': ['Alta', 'Media', 'Baja'],
    'Impacto': ['Crítico', 'Moderado', 'Leve']
})

# Mapear escalas cualitativas a cuantitativas
mapping = {'Baja':1, 'Media':2, 'Alta':3, 'Leve':1, 'Moderado':2, 'Crítico':3}
df['P_num'] = df['Probabilidad'].map(mapping)
df['I_num'] = df['Impacto'].map(mapping)

# Cálculo del riesgo
df['Riesgo'] = df['P_num'] * df['I_num']

# Pivot table
matrix = df.pivot(index='Probabilidad', columns='Impacto', values='Riesgo')
matrix = matrix.reindex(index=['Baja','Media','Alta'], columns=['Leve','Moderado','Crítico'])

# Visualización con formato flotante redondeado
plt.figure(figsize=(6, 4))
sns.heatmap(matrix, annot=True, cmap='Reds', fmt='.0f')  # <-- cambio aquí
plt.title('Matriz de Probabilidad vs Impacto (Datos reales)')
plt.xlabel('Impacto')
plt.ylabel('Probabilidad')
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="1.2.3"></a>
# ### 1.2.3. Interpretación Cuantitativa

# %% [markdown]
# * Esta matriz convierte juicios cualitativos en valores numéricos objetivos, lo que permite tomar decisiones cuantitativamente justificadas.
# * Es aplicable para priorizar variables, analizar riesgos experimentales o definir escenarios críticos en simulaciones.
# * Su uso es común en ingeniería de proyectos, modelado de sistemas y validación de experimentos.
# * Usa datos numéricos y reglas consistentes.
# * Permite reproducibilidad y comparación de resultados.
# * Es una herramienta previa a modelos estadísticos o de optimización.
# * Puentea lo cualitativo y lo cuantitativo, representando lo subjetivo con valores escalables.

# %% [markdown]
# > _Después de cuantificar riesgos, otra tarea inicial en un análisis cuantitativo es organizar y representar datos medidos. Para esto, se utilizan reglas como Sturges, que ayudan a construir histogramas óptimos y detectar patrones._

# %% [markdown]
# <a id="1.3"></a>
# ## 1.3. Clasificación de Datos: Aplicación de la Regla de Sturges

# %% [markdown]
# Cuando se recolectan datos experimentales o simulados (por ejemplo, expectativas de observables cuánticos, tiempos de respuesta en un sistema, tasas de crecimiento), una de las primeras tareas del análisis cuantitativo es:
#
# * Agrupar los datos en clases o intervalos.
# * Construir histogramas para explorar la distribución.
# * Detectar asimetrías, sesgos, outliers o patrones ocultos.
#
# > Pero… ¿cómo saber cuántas clases usar en un histograma?
#
# _Ahí es donde entra la Regla de Sturges._

# %% [markdown]
# <a id="1.3.1"></a>
# ### 1.3.1. Regla de Sturges: Definición

# %% [markdown]
# La Regla de Sturges es una fórmula empírica que estima el número óptimo de clases (bins) para representar un conjunto de datos en un histograma.

# %% [markdown]
# <div align="center">
# $k=1+log_2(n)$
# </div>

# %% [markdown]
# Donde:
# * $k:$  número recomendado de clases
# * $n:$  número de observaciones
#
# También puede expresarse como:

# %% [markdown]
# <div align="center">
# $k=[log_2(n)+1]$
# </div>

# %% [markdown]
# Esto permite evitar subrepresentar o sobrecargar los histogramas, y obtener una visión clara de la distribución.

# %% [markdown]
# <a id="1.3.2"></a>
# ### 1.3.2. Implementación en Python

# %% [markdown]
# > Usaremos un dataset real: el famoso Iris dataset, que contiene medidas continuas como longitud del sépalo, longitud del pétalo, etc. Puedes descargarlo desde [UCI Machine Learning Repository](https://www.kaggle.com/datasets/uciml/iris) o usar directamente la URL público.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import pandas as pd

# Cargar Iris dataset desde GitHub
url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
df = pd.read_csv(url)

# Variable continua: sepal_length
datos = df['sepal_length']

n = len(datos)
k = math.ceil(math.log2(n) + 1)
print(f"Número de clases según Sturges: {k}")

plt.figure(figsize=(8,5))
sns.histplot(datos, bins=k, kde=True, color='teal')
plt.title(f'Histograma de Longitud de Sépalo (k = {k} clases)')
plt.xlabel('Longitud de Sépalo (cm)')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Número de clases según Sturges: 9

# %% [markdown]
# <a id="1.3.3"></a>
# ### 1.3.3. Interpretación Cuantitativa

# %% [markdown]
# * Esta técnica es objetiva, reproducible y basada en el tamaño muestral, lo cual es clave para estudios experimentales o simulaciones.
# * Evita la subjetividad en la selección de clases, que podría alterar la interpretación visual de los datos.
# * Es especialmente útil en fases exploratorias de análisis cuantitativo, como previo al PCA, regresiones, clustering, o ANOVA.
# * Sistematiza la visualización inicial de datos.
# * Permite hacer inferencias preliminares sobre la forma de la distribución.
# * Sienta las bases para análisis más complejos (test de normalidad, selección de variables, validación de supuestos).

# %% [markdown]
# <a id="1.3.4"></a>
# ### 1.3.4. Comparación con otros métodos

# %% [markdown]
# Otras reglas para determinar el número de clases incluyen:
#
# | Método                | Fórmula                              | Comentario                          |
# | --------------------- | ------------------------------------ | ----------------------------------- |
# | **Sturges**           | $k = 1 + \log_2(n)$                  | Estándar, ideal para datos normales |
# | **Freedman–Diaconis** | $h = 2 \cdot IQR / \sqrt[3]{n}$      | Más robusta ante outliers           |
# | **Scott**             | $h = 3.5 \cdot \sigma / \sqrt[3]{n}$ | Basada en desviación estándar       |

# %% [markdown]
# <a id="1.4"></a>
# ## 1.4. Diferencias entre el Análisis Cuantitativo y Cualitativo

# %% [markdown]
# En el diseño de proyectos científicos y de ingeniería, el enfoque de análisis elegido —cuantitativo o cualitativo— determina el tipo de evidencia que se obtiene, la forma de estructurar los datos y el método de interpretación de los resultados.

# %% [markdown]
# A continuación, se contrastan ambos enfoques usando dos herramientas como referencia práctica:
#
# * La Matriz de Impacto, que nace en un contexto más cualitativo pero puede formalizarse cuantitativamente.
# * La Regla de Sturges, que es una técnica completamente cuantitativa.

# %% [markdown]
# <a id="1.4.1"></a>
# ### 1.4.1. Comparación Conceptual

# %% [markdown]
# | Característica              | Análisis Cuantitativo                       | Análisis Cualitativo                          |
# | --------------------------- | ------------------------------------------- | --------------------------------------------- |
# | **Naturaleza de los datos** | Numéricos, medibles, objetivos              | Categóricos, subjetivos, descriptivos         |
# | **Tipo de razonamiento**    | Deductivo, hipotético-deductivo             | Inductivo o interpretativo                    |
# | **Enfoque**                 | Explicación de fenómenos mediante variables | Comprensión profunda del fenómeno             |
# | **Instrumentos comunes**    | Encuestas, sensores, simulaciones, modelos  | Entrevistas, observaciones, análisis textual  |
# | **Resultados**              | Estadísticos, generalizables, replicables   | Ricos en contexto, no generalizables          |
# | **Ejemplo práctico**        | Regla de Sturges (análisis de distribución) | Juicio experto al construir matriz de impacto |

# %% [markdown]
# <a id="1.4.2"></a>
# ### 1.4.2. Aplicación a la Matriz de Probabilidad de Impacto

# %% [markdown]
# | Etapa de uso              | Cualitativo                                 | Cuantitativo                                       |
# | ------------------------- | ------------------------------------------- | -------------------------------------------------- |
# | **Construcción inicial**  | Requiere juicio experto para estimar riesgo | Puede usarse historial de datos reales             |
# | **Asignación de escalas** | Baja, media, alta (descripción subjetiva)   | Valores 1, 2, 3 (escala ordinal cuantificada)      |
# | **Propósito**             | Visualizar riesgo percibido                 | Priorizar acciones con base en criterios numéricos |
# | **Ejemplo de transición** | Estimar que un riesgo es "alto impacto"     | Asignar valor 3 de impacto → Riesgo = Prob × 3     |

# %% [markdown]
# > La matriz puede comenzar como una herramienta cualitativa, pero al cuantificar sus elementos, se convierte en una técnica de análisis cuantitativo reproducible.

# %% [markdown]
# <a id="1.4.3"></a>
# ### 1.4.3. Aplicación a la Regla de Sturges

# %% [markdown]
# | Etapa de uso                | Cualitativo                                  | Cuantitativo                                       |
# | --------------------------- | -------------------------------------------- | -------------------------------------------------- |
# | **Motivación**              | Deseo de visualizar la distribución de datos | Representación estructurada y optimizada           |
# | **Número de clases (bins)** | Elegido arbitrariamente                      | Calculado con fórmula basada en el tamaño muestral |
# | **Análisis visual**         | Gráfico subjetivo o no representativo        | Histograma balanceado y comparable                 |
# | **Ejemplo**                 | “Se ve bien con 5 clases”                    | “Según Sturges, se requieren 7 clases”             |

# %% [markdown]
# > El análisis cualitativo puede guiarnos a explorar un fenómeno, pero la formalización cuantitativa permite objetividad, comparación y reproducibilidad, características esenciales del análisis científico.

# %% [markdown]
# <a id="1.4.3"></a>
# ### 1.4.4. Conexión entre ambos enfoques

# %% [markdown]
# Aunque diferentes, los enfoques cualitativo y cuantitativo no son excluyentes, sino complementarios.
#
# Por ejemplo:
#
# * En la matriz de impacto, el juicio experto (cualitativo) inicia el análisis, pero es la cuantificación la que permite su uso en simulaciones y modelos de decisión.
# * En la clasificación de datos, la intuición puede guiar el análisis, pero son las fórmulas como la de Sturges las que dan precisión y rigor.

# %% [markdown]
# <a id="1.4.5"></a>
# ### 1.4.5. Conclusión

# %% [markdown]
# Las herramientas vistas —la Matriz de Impacto y la Regla de Sturges— ilustran la evolución natural del pensamiento científico:
#
# 1. Se parte de observaciones y percepciones cualitativas.
# 2. Se estructuran en modelos cuantitativos.
# 3. Se validan, visualizan y comunican los resultados mediante métricas objetivas.
#
# > Este tránsito es el fundamento del análisis cuantitativo aplicado, especialmente en disciplinas como la ingeniería, la física computacional, la gestión de riesgos o la ciencia de datos.

# %% [markdown]
# <a id="2"></a>
# # 2. Tipos de investigación cuantitativa

# %% [markdown]
# <a id="2.1"></a>
# ## 2.1. Investigación Experimental

# %% [markdown]
# Es el tipo más riguroso de investigación cuantitativa. Se caracteriza por:
#
# * Manipulación directa de la VI.
# * Control estricto de las variables externas.
# * Asignación aleatoria de sujetos a grupos.
#
# 🎯 Su objetivo es establecer relaciones de **causalidad**.

# %% [markdown]
# 🔬 **Ejemplo:**
#
# > Evaluar el efecto de un conservante natural (como extracto vegetal) en la inhibición del crecimiento bacteriano, midiendo la absorbancia (VD) a lo largo de los días.
#
# ✅ El uso de **ANOVA** permite saber si existen diferencias significativas entre los grupos. Luego, Tukey HSD revela entre qué grupos están esas diferencias.

# %% [markdown]
# <div align="center"><img width="600px" style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,...">

# %% [markdown]
# ```
# 📅 Día 1:
#
# ANOVA:
#                   sum_sq    df          F        PR(>F)
# C(Tratamiento)  0.016435   2.0  35.103586  3.086623e-08
# Residual        0.006320  27.0        NaN           NaN
#
# Tukey HSD:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#     group1        group2    meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------
# Conservante A Conservante B  -0.0086 0.4292 -0.0256 0.0083  False
# Conservante A       Control   0.0448    0.0  0.0278 0.0617   True
# Conservante B       Control   0.0534    0.0  0.0364 0.0704   True
# -----------------------------------------------------------------
#
# 📅 Día 2:
#
# ANOVA:
#                   sum_sq    df          F        PR(>F)
# C(Tratamiento)  0.024471   2.0  35.019576  3.159559e-08
# Residual        0.009433  27.0        NaN           NaN
#
# Tukey HSD:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
# Conservante A Conservante B   -0.031 0.0027 -0.0517 -0.0102   True
# Conservante A       Control   0.0389 0.0002  0.0181  0.0596   True
# Conservante B       Control   0.0698    0.0  0.0491  0.0905   True
# ------------------------------------------------------------------

# %% [markdown]
# 🧠 **INTERPRETACIÓN:**
#
# * El **ANOVA** te dice si al menos un tratamiento tiene un efecto diferente sobre la absorbancia (crecimiento bacteriano).
# * El **Tukey HSD** te muestra cuáles tratamientos difieren significativamente entre sí.
# * Puedes observar cómo cambia esto con el tiempo (día a día).

# %% [markdown]
# <a id="2.2"></a>
# ## 2.2. Investigación Cuasi-experimental

# %% [markdown]
# Se utiliza cuando no es posible aplicar aleatoriedad completa. Por ejemplo:
#
# * Grupos ya formados (escuelas, plantas industriales, comunidades).
# * Menor control de variables externas, pero aún se manipula la VI.

# %% [markdown]
# 👨‍🏫 **Ejemplo:**
#
# > Comparar el rendimiento de productos procesados en distintas líneas de producción, sin posibilidad de asignar condiciones aleatoriamente.
#
# 🔎 Se puede aplicar **ANOVA de medidas repetidas** o modelos mixtos para controlar parcialmente los factores no aleatorizados.

# %% [markdown]
# <div align="center"><img width="600px" style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,...">

# %% [markdown]
# ```
#     Mixed Linear Model Regression Results
# ===============================================================
# Model:              MixedLM   Dependent Variable:   Rendimiento
# No. Observations:   150       Method:               REML
# No. Groups:         10        Scale:                7.3613
# Min. group size:    15        Log-Likelihood:       -369.2485
# Max. group size:    15        Converged:            Yes
# Mean group size:    15.0
# ---------------------------------------------------------------
#                   Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# ---------------------------------------------------------------
# Intercept        102.673    0.627 163.726 0.000 101.444 103.903
# Linea[T.Línea B]  -4.483    0.543  -8.262 0.000  -5.547  -3.420
# Linea[T.Línea C]  -9.669    0.543 -17.819 0.000 -10.733  -8.606
# Group Var          2.460    0.529
# ===============================================================
#
# ```

# %% [markdown]
# 🧠 **INTERPRETACIÓN:**
#
# * Si los coeficientes de la línea son significativos (p < 0.05), entonces el rendimiento sí difiere entre líneas.
# * El uso del día como efecto aleatorio te permite controlar parcialmente por las variaciones temporales no aleatorizadas.

# %% [markdown]
# <a id="2.3"></a>
# ## 2.3. Investigación Cuantitativa No Experimental

# %% [markdown]
# No hay manipulación de variables. Se basa en la observación, registro y análisis estadístico de fenómenos existentes.
#
# * **_Descriptiva:_** Describe características de una población o fenómeno.
# * **_Correlacional:_** Examina relaciones entre variables sin establecer causalidad.

# %% [markdown]
# 💧 **Ejemplo:**
#
# > Analizar la relación entre turbidez, conductividad y pH en cuerpos de agua de distintas regiones.
#
# 🧠 Aquí, **PCA** es útil para reducir variables y encontrar las más relevantes o representativas del comportamiento global.

# %% [markdown]
# <div align="center"><img width="600px" style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,...">

# %% [markdown]
# 🧩 **iNTERPRETACIÓN:**
#
# * PC1 y PC2 son combinaciones de las variables originales (turbidez, conductividad, pH).
# * Los grupos separados por región indican que ciertas regiones tienen características fisicoquímicas distintas.
# * Puedes identificar qué variables contribuyen más a cada componente analizando pca.components_.

# %% [markdown]
# <a id="4"></a>
# # 3. Ejemplos Prácticos

# %% [markdown]
# <a id="3.1"></a>
# ## 3.1. Ejemplo 1: PCA (Análisis de Componentes Principales)

# %% [markdown]
# * Se aplica cuando hay muchas variables y se desea encontrar patrones.
# * Permite reducir la dimensionalidad sin perder información relevante.
#
# Se usa para:
# * Evaluar calidad de productos.
# * Detectar variables redundantes.
# * Visualizar agrupaciones naturales.

# %% [markdown]
# 🧪 **Ejemplo aplicado:**
#
# > Evaluar las propiedades fisicoquímicas de bebidas fermentadas con frutas andinas. PCA mostró cómo se agrupan según su perfil químico.

# %% [markdown]
# <div align="center"><img width="700px" style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,...">

# %% [markdown]
# <a id="3.2"></a>
# ## 3.2. Ejemplo 2: ANOVA + Tukey HSD

# %% [markdown]
# * **ANOVA** permite comparar medias de múltiples grupos.
# * **Tukey HSD** identifica entre cuáles grupos hay diferencias significativas.

# %% [markdown]
# 👨‍🔬 **Ejemplo aplicado:**
#
# > Estudio de concentración de un compuesto natural en muestras de alimentos durante distintos días de almacenamiento. Se aplicó ANOVA por día y grupo de tratamiento; luego, Tukey mostró qué tratamientos conservaban mejor las propiedades.

# %% [markdown]
# <div align="center"><img width="900px" style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,...">

# %% [markdown]
# <a id="3.3"></a>
# ## 3.3. Ejemplo 3: Aplicación en Ciencia e Ingeniería

# %% [markdown]
# * Uso de estas técnicas para validar sensores, materiales, procesos industriales.
#
# Permite tomar decisiones basadas en datos en áreas como:
#
# * Control de calidad.
# * Optimización de procesos.
# * Desarrollo de productos.

# %% [markdown]
# 🎯 **Ejemplo:**
#
# > Una empresa desarrolla un sistema automático basado en visión computarizada para detectar defectos en empaques de productos alimenticios (como roturas, manchas, o etiquetas mal colocadas).
# Para validar el sistema, se comparan los resultados (medidas de precisión de detección) en tres líneas de producción distintas que operan bajo condiciones ligeramente diferentes.

# %% [markdown]
# 📊 **Diseño del experimento:**
#
# * Variable dependiente (VD): Precisión (%) del sistema de visión en detectar correctamente los defectos.
# * Variable independiente (VI): Línea de producción (A, B, C).
# * Hipótesis nula (H₀): No hay diferencia significativa en la precisión del sistema entre las líneas.

# %% [markdown]
# #### **Aplicación:**

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Simular un dataset
np.random.seed(42)

# Tres líneas de producción con diferente nivel de defectos detectados por un sistema automático
data = {
    'Linea': ['Línea A']*10 + ['Línea B']*10 + ['Línea C']*10,
    'DefectosDetectados': np.concatenate([
        np.random.normal(5, 1, 10),   # Línea A
        np.random.normal(7, 1, 10),   # Línea B
        np.random.normal(6.5, 1, 10)  # Línea C
    ])
}

df = pd.DataFrame(data)

# Visualizar
plt.figure(figsize=(8, 5))
sns.boxplot(x='Linea', y='DefectosDetectados', data=df, hue='Linea', palette="Set2", legend=False)
plt.title('Defectos detectados por línea de producción')
plt.ylabel('Número de defectos detectados')
plt.show()

# ANOVA
modelo = ols('DefectosDetectados ~ C(Linea)', data=df).fit()
anova_tabla = sm.stats.anova_lm(modelo, typ=2)
print("\n📊 Tabla ANOVA:\n")
print(anova_tabla)

# Tukey HSD para comparar pares
tukey = pairwise_tukeyhsd(endog=df['DefectosDetectados'], groups=df['Linea'], alpha=0.05)
print("\n Resultados de Tukey HSD:\n")
print(tukey)

# Graficar resultados de Tukey
tukey.plot_simultaneous(comparison_name='Línea A')
plt.title('Comparaciones múltiples: Tukey HSD')
plt.show()
# Out:
# ,📊 Tabla ANOVA:
# ,
# ,             sum_sq    df         F    PR(>F)
# ,C(Linea)   4.244473   2.0  3.626337  0.040275
# ,Residual  15.801175  27.0       NaN       NaN
# ,
# , Resultados de Tukey HSD:
# ,
# , Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ,=====================================================
# , group1  group2 meandiff p-adj   lower  upper  reject
# ,-----------------------------------------------------
# ,Línea A Línea B   0.7613 0.0849  -0.087 1.6095  False
# ,Línea A Línea C   0.8301  0.056 -0.0182 1.6784  False
# ,Línea B Línea C   0.0688  0.978 -0.7794 0.9171  False
# ,-----------------------------------------------------

# %% [markdown]
# #### **Interpretación:**
# * **ANOVA** te dice si existe alguna diferencia significativa entre las líneas de producción respecto a la cantidad de defectos detectados automáticamente.
# * **Tukey HSD** revela entre qué líneas existen esas diferencias (por ejemplo, si la Línea A tiene menos defectos que la B o C).
# * Esto es útil en validación de sistemas automáticos para verificar si el sistema detecta diferencias reales entre procesos productivos.

# %% [markdown]
# <a id="4"></a>
# # 4. Aplicaciones Prácticas del Análisis Cuantitativo

# %% [markdown]
# <a id="4.1"></a>
# ## 4.1. Ejemplo 1: Interpolación con Matriz de Vandermonde

# %% [markdown]
# ### 📘 Fundamento Teórico
#
# La **interpolación polinómica** busca construir una función que pase exactamente por un conjunto de puntos conocidos \((x_i, y_i)\). Una forma sistemática de hacerlo es utilizando la **Matriz de Vandermonde**, una matriz cuadrada en la que cada fila corresponde a una potencia del valor \(x_i\).
#
# La matriz se define como:
#
# <div align="center">
# $
# V = \begin{bmatrix}
# 1 & x_1 & x_1^2 & \cdots & x_1^{n-1} \\
# 1 & x_2 & x_2^2 & \cdots & x_2^{n-1} \\
# \vdots & \vdots & \vdots & & \vdots \\
# 1 & x_n & x_n^2 & \cdots & x_n^{n-1}
# \end{bmatrix}
# $
# </div>
#
# Al resolver el sistema lineal
#
# <div align="center">
# $V \cdot a = y$
# </div>
#
# se obtienen los coeficientes del polinomio interpolante.
#
# ### 🎯 Aplicación Cuantitativa
#
# Este método permite generar funciones que aproximan datos experimentales, útil en calibración, diseño de curvas, o ingeniería de control. Su implementación es completamente determinista y cuantitativa.

# %% [markdown]
# ### 🔍 Implementación en Python
#
# > Estimar un polinomio que pase por un conjunto de puntos conocidos utilizando álgebra lineal. Este método es fundamental para aproximaciones numéricas, modelado físico, y reconstrucción de señales.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nuevos puntos
x = np.array([1, 2.5, 4])
y = np.array([3, 6, 10])
V = np.vander(x, increasing=True)
coefs = np.linalg.solve(V, y)

print("Coeficientes del polinomio interpolado:", coefs)

x_plot = np.linspace(0.5, 4.5, 100)
y_plot = coefs[0] + coefs[1]*x_plot + coefs[2]*x_plot**2

plt.plot(x_plot, y_plot, label='Polinomio interpolado')
plt.scatter(x, y, color='red', label='Puntos conocidos')
plt.title("Interpolación (versión de evaluación)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Coeficientes del polinomio interpolado: [1.55555556 1.22222222 0.22222222]

# %% [markdown]
# ### 📊 **Interpretación**
#
# > Este ejercicio demuestra cómo el análisis cuantitativo permite construir un modelo determinístico (el polinomio) a partir de datos discretos. Es especialmente útil en simulaciones científicas donde se requieren aproximaciones suaves de datos experimentales.

# %% [markdown]
# <a id="4.2"></a>
# ## 4.2. Ejemplo 2: Ajuste de Regresión Lineal Simple

# %% [markdown]
# ### 📘 Fundamento Teórico
#
# La **regresión lineal** es una técnica estadística que modela la relación entre una variable dependiente $( y )$ y una o más variables independientes $( x )$ asumiendo que la relación es lineal:
#
# <div align="center">
# $y = \beta_0 + \beta_1 x + \epsilon$
# </div>
#
# donde:
#
# - $( \beta_0 )$ es la ordenada al origen (intercepto),
# - $( \beta_1 )$ es la pendiente (coeficiente que mide el cambio esperado en $( y )$ por unidad de cambio en $( x )$),
# - $( \epsilon )$ es el término de error aleatorio.
#
# El objetivo es encontrar los coeficientes $( \beta_0 )$ y $( \beta_1 )$ que minimizan la suma de los cuadrados de los residuos (diferencias entre valores observados y valores predichos).
#
# ### 🎯 Aplicación Cuantitativa
#
# La regresión lineal se usa para:
#
# - Predecir valores futuros o desconocidos,
# - Evaluar la fuerza y dirección de la relación entre variables,
# - Identificar tendencias y patrones en datos experimentales o económicos.
#
# Este método es fundamental en análisis cuantitativo por su simplicidad y capacidad para inferir relaciones causales.

# %% [markdown]
# ### 🔍 Implementación en Python
#
# Estimar la relación lineal entre dos variables numéricas mediante un modelo de regresión lineal simple. Este método es fundamental en estadística, ciencia de datos e ingeniería para modelar tendencias, predecir valores y verificar hipótesis causales.
#
# > Modelo general:
#
# <div align="center">
# $y = \beta_0 + \beta_1 x + \varepsilon$
# </div>
#
# donde:
#
# - $y$ es la variable dependiente (respuesta),
# - $x$ es la variable independiente (predictora),
# - $\beta_0$ es la ordenada al origen (intercepto),
# - $\beta_1$ es la pendiente,
# - $\varepsilon$ es el error aleatorio.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm

# Simulación de datos con relación lineal
np.random.seed(42)
x = np.linspace(0, 10, 50)
y = 3 * x + 4 + np.random.normal(0, 2, size=len(x))

# Crear DataFrame
df = pd.DataFrame({'x': x, 'y': y})

# Ajustar modelo de regresión lineal
X = sm.add_constant(df['x'])  # Agrega el término constante (intercepto)
modelo = sm.OLS(df['y'], X).fit()

# Mostrar resumen del modelo
print(modelo.summary())

# Visualización
plt.figure(figsize=(8, 5))
sns.regplot(x='x', y='y', data=df, line_kws={"color": "red"}, ci=95)
plt.title("Regresión Lineal: Relación entre x e y")
plt.xlabel("Variable Independiente (x)")
plt.ylabel("Variable Dependiente (y)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#                             OLS Regression Results
# ,==============================================================================
# ,Dep. Variable:                      y   R-squared:                       0.956
# ,Model:                            OLS   Adj. R-squared:                  0.955
# ,Method:                 Least Squares   F-statistic:                     1049.
# ,Date:                Wed, 03 Sep 2025   Prob (F-statistic):           2.83e-34
# ,Time:                        18:33:31   Log-Likelihood:                -100.80
# ,No. Observations:                  50   AIC:                             205.6
# ,Df Residuals:                      48   BIC:                             209.4
# ,Df Model:                           1
# ,Covariance Type:            nonrobust
# ,==============================================================================
# ,                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ## 📊 Interpretación
#
# * El modelo estima los coeficientes $\beta_0$ y $\beta_1$ que mejor ajustan una línea recta a los datos.
# * La salida de $summary()$ muestra:
#     - Coeficientes estimados, error estándar, estadístico t y p-valor.
#     - $R^2$, que indica qué proporción de la varianza de $y$ es explicada por $x$.
#     - $p-value$ bajo $(< 0.05)$ indica que la relación entre las variables es estadísticamente significativa.
#     - La gráfica muestra el ajuste lineal y el intervalo de confianza.

# %% [markdown]
# <a id="4.3"></a>
# ## 4.3. Ejemplo 3: Solución de una Ecuación Diferencial Ordinaria (EDO) con el Método de Euler

# %% [markdown]
# ### 📘 Fundamento Teórico
#
# El **método de Euler** es uno de los métodos numéricos más simples para resolver ecuaciones diferenciales ordinarias (EDO) de la forma:
#
# <div align="center">
# $\frac{dy}{dt} = f(t, y), \quad y(t_0) = y_0$
# </div>
#
# Se aproxima la solución utilizando la fórmula recursiva:
#
# <div align="center">
# $y_{n+1} = y_n + h \cdot f(t_n, y_n)$
# </div>
#
# donde \(h\) es el tamaño del paso.
#
# ### 🎯 Aplicación Cuantitativa
#
# El método de Euler proporciona una aproximación paso a paso de la solución de un modelo dinámico. Su simplicidad lo hace útil para visualizar rápidamente la evolución de sistemas, con validación gráfica y numérica.

# %% [markdown]
# ### 🔍 Implementación en Python
#
# > Resolver numéricamente una EDO de primer orden usando el método de Euler, una técnica fundamental en análisis numérico para modelar sistemas dinámicos, reacciones químicas, crecimiento, y más.
#
# >EDO dada:
# <div align="center">
# $\frac{dy}{dt} = -3y, \quad y(0) = 2$
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# EDO: dy/dt = -3y, y(0) = 2
t0, y0 = 0, 2
h = 0.1
n = 25

t_vals = [t0]
y_vals = [y0]

for _ in range(n):
    y_next = y_vals[-1] - 3 * y_vals[-1] * h
    t_next = t_vals[-1] + h
    y_vals.append(y_next)
    t_vals.append(t_next)

# Solución exacta
t_exact = np.linspace(0, 2.5, 100)
y_exact = 2 * np.exp(-3 * t_exact)

# Gráfico
plt.plot(t_vals, y_vals, 'o-', label='Euler (Aprox.)')
plt.plot(t_exact, y_exact, '--', label='Solución Exacta')
plt.title("EDO: dy/dt = -3y con Método de Euler")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 📊 Interpretación
#
# * El método de Euler aproxima la solución de una EDO paso a paso, usando derivadas evaluadas en puntos discretos.
# * Se observa que, para pasos pequeños (h = 0.1), la solución aproximada sigue de cerca la curva exacta.
# * Esto ilustra cómo el análisis cuantitativo permite simular la evolución de sistemas dinámicos incluso sin una solución analítica directa.

# %% [markdown]
# <a id="4.4"></a>
# ## 4.4. Ejemplo 4: Modelo Logístico de Crecimiento Poblacional

# %% [markdown]
# ### 📘 Fundamento Teórico
#
# El modelo logístico describe el crecimiento de una población limitada por un entorno finito. Se basa en la ecuación diferencial:
#
# <div align="center">
# $\frac{dP}{dt} = rP \left(1 - \frac{P}{K}\right)$
# </div>
#
# donde:
#
# - $(P)$ es la población en el tiempo $(t)$,
# - $(r)$ es la tasa de crecimiento,
# - $(K)$ es la capacidad máxima del entorno (capacidad de carga).
#
# Este modelo refleja cómo la tasa de crecimiento disminuye a medida que la población se acerca a su límite.
#
# ### 🎯 Aplicación Cuantitativa
#
# Es ampliamente utilizado en biología, ecología, economía y sociología para simular fenómenos de crecimiento limitado. Permite validar hipótesis sobre sostenibilidad y predicción de puntos de saturación.

# %% [markdown]
# ### 🔍 Implementación en Python
#
# > Simular la evolución de una población limitada por recursos, usando el modelo logístico, ampliamente utilizado en ecología, epidemiología, economía y sociología.
#
# > Modelo:
# <div align="center">
# $\frac{dP}{dt} = rP\left(1 - \frac{P}{K}\right)$
# </div>

# %%
import matplotlib.pyplot as plt

# Parámetros
r = 0.3         # Tasa de crecimiento
K = 800         # Capacidad de carga
P0 = 50         # Población inicial
h = 0.2         # Paso de tiempo
n = 60          # Iteraciones

P_vals = [P0]
t_vals = [0]

for _ in range(n):
    P = P_vals[-1]
    dP = r * P * (1 - P / K)
    P_vals.append(P + dP * h)
    t_vals.append(t_vals[-1] + h)

plt.plot(t_vals, P_vals, label='Crecimiento logístico')
plt.title("Simulación de Crecimiento Poblacional (Modelo Logístico)")
plt.xlabel("Tiempo")
plt.ylabel("Población")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 📊 Interpretación
#
# * El modelo muestra cómo una población crece rápidamente al inicio y luego se estabiliza conforme se acerca al límite ambiental (K).
# * Es un ejemplo clásico de dinámica no lineal y sirve para enseñar cómo los modelos cuantitativos pueden capturar comportamientos complejos con pocas variables y reglas simples.

# %% [markdown]
# <a id="4.5"></a>
# ## 4.5. Ejemplo 5: Análisis de Componentes Principales (PCA)

# %% [markdown]
# ### 📘 Fundamento Teórico
#
# El **Análisis de Componentes Principales (PCA)** es una técnica de reducción de dimensionalidad que transforma un conjunto de variables correlacionadas en un nuevo conjunto de variables no correlacionadas llamadas **componentes principales**.
#
# Estas componentes están ordenadas según la varianza explicada: el primer componente explica la mayor parte de la varianza, el segundo la siguiente, y así sucesivamente.
#
# ### 🎯 Aplicación Cuantitativa
#
# PCA permite analizar grandes conjuntos de datos de forma más eficiente, visualizar patrones ocultos, y eliminar redundancia. Es muy útil en ciencia de datos, ingeniería, y reconocimiento de patrones.

# %% [markdown]
# ### 🔍 Implementación en Python
#
# Reducir la dimensionalidad de un conjunto de datos multivariado para facilitar su análisis visual y estadístico, preservando la mayor parte de la varianza original.
#
# > PCA transforma las variables originales en componentes principales no correlacionadas, ordenadas según su capacidad de explicar la varianza.

# %%
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datos sintéticos
np.random.seed(123)
X = np.random.normal(loc=5, scale=2, size=(120, 4))
df = pd.DataFrame(X, columns=['A', 'B', 'C', 'D'])

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

print("Proporción de varianza explicada:", pca.explained_variance_ratio_)

# Gráfico
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.7, c='orange')
plt.title("PCA: Reducción de Dimensión (Versión Alternativa)")
plt.xlabel("Componente 1")
plt.ylabel("Componente 2")
plt.grid(True)
plt.show()
# Out:
# Proporción de varianza explicada: [0.30674847 0.27402849]

# %% [markdown]
# ### 📊 Interpretación
#
# * PCA identifica los ejes de mayor variabilidad en los datos, lo cual permite reducir dimensiones sin perder demasiada información.
# * En este caso, las dos primeras componentes explican una parte sustancial de la varianza total, permitiendo visualizar en 2D datos originalmente en 4D.
# * Es una técnica fundamental en el análisis cuantitativo moderno, útil en bioinformática, ingeniería, finanzas, IA y más.

# %% [markdown]
# <a id="5"></a>
# # 5. Ejercicios de Evaluación

# %% [markdown]
# <a id="5.1"></a>
# ## 5.1. Ejercicio 1: Interpolación con Matriz de Vandermond

# %% [markdown]
# 🎯 **Objetivo:**
#
# * Interpolar un polinomio de segundo grado que pase por tres puntos dados usando la matriz de Vandermonde.
#
#
# 📌 **Instrucciones:**
#
# 1. Define tres pares de puntos $(x_i, y_i)$
#  que serán usados para construir el polinomio.
#
# 2. Completa la línea de código que construye la matriz de Vandermonde con `np.vander(x, increasing=True)`.
#
# 3. Usa `np.linalg.solve()` para resolver el sistema y obtener los coeficientes del polinomio.
#
# 4. Evalúa el polinomio sobre un rango de valores `x_plot` usando los coeficientes obtenidos.
#
# 5. Grafica el polinomio interpolado y los puntos originales.
#
# 6. Agrega una breve interpretación: ¿cómo cambia la curva si modificas los puntos?
#
#
# ⚡ **Resultado Esperado:**
#
# Un gráfico suave que pase exactamente por los tres puntos definidos.

# %% [markdown]
# <a id="5.2"></a>
# ## 5.2. Ejercicio 2: Solución de una Ecuación Diferencial con Método de Euler

# %% [markdown]
# 🎯 **Objetivo:**
#
# * Resolver numéricamente la EDO $\frac{𝑑𝑦}{𝑑𝑡}=−2𝑦$ con condición inicial $y(0)=1$, utilizando el método de Euler.
#
#
# 📌 **Instrucciones:**
#
# 1. Define los parámetros iniciales: paso de integración `h`, número de pasos `n`, y condición inicial `y0 = 1`.
# 2. Completa el ciclo que aplica el método de Euler:
#
#       * Usa la fórmula $y_{n+1}= y_n+h \cdot f(y_n)$, donde $f(y)=−2y$.
#
# 3. Calcula también la solución exacta $y(t)=e^{-2t}$  para comparar.
# 4. Grafica ambas soluciones en el mismo gráfico.
# 5. Comenta las diferencias observadas entre la solución numérica y la exacta. ¿Qué pasa si reduces el paso h?
#
# ⚡ **Resultado Esperado:**
#
# Un gráfico con dos curvas: una con puntos (Euler) y una línea continua (exacta), que muestran la evolución decreciente de $y$.

# %% [markdown]
# <a id="5.3"></a>
# ## 5.3. Ejercicio 3: Modelo Logístico de Crecimiento Poblacional

# %% [markdown]
# 🎯 **Objetivo:**
#
# * Simular el crecimiento de una población bajo el modelo logístico con capacidad de carga limitada.
#
# 📌 **Instrucciones:**
#
# 1. Define los parámetros:
#
#       * `r`: tasa de crecimiento (ej. 0.5)
#       * `K`: capacidad máxima del ambiente (ej. 1000)
#       * `P0`: población inicial (ej. 100)
#       * `h`: paso del tiempo (ej. 0.1)
#       * `n`: número de iteraciones (ej. 100)
#
# 2. Implementa el método de Euler con la ecuación: $P_{n+1}=P_n +h \cdot r P_n \left(1-\frac{P_n}{k}\right)$
# 3. Grafica el crecimiento poblacional sobre el tiempo.
# 4. Experimenta con diferentes valores de `r`, `K` y `P0`. ¿Cómo afectan la curva?
#
# ⚡ **Resultado Esperado:**
#
# Una curva que crece rápido al inicio y luego se estabiliza al llegar a la capacidad de carga $K$.

# %% [markdown]
# <a id="5.4"></a>
# ## 5.4. Ejercicio 4:  PCA (dataset + análisis)

# %% [markdown]
# 🎯 **Objetivo:**
#
# * Reducir la dimensionalidad de un conjunto de datos utilizando PCA y visualizar los datos en dos dimensiones.
#
# 📌 **Instrucciones:**
#
# 1. Genera un conjunto de datos aleatorios de tamaño $(100,5)$ usando `np.random.rand()`.
#
# 2. Aplica `PCA(n_components=2)` con `sklearn.decomposition.PCA` sobre el dataset.
#
# 3. Completa la línea que imprime la varianza explicada por cada componente.
#
# 4. Grafica los datos proyectados sobre los dos primeros componentes.
#
# 5. Interpreta:
#
#       * ¿Qué proporción de la varianza retiene el PCA?
#
#       * ¿Qué observarías si aumentas o reduces el número de variables?
#
# ⚡ **Resultado Esperado:**
#
# Un gráfico de dispersión en 2D donde cada punto representa un dato reducido a sus dos componentes principales.

# %% [markdown]
# <a id="5.5"></a>
# ## 5.5. Ejercicio 5: Simulación Cuántica de Qubits con QuTiP

# %% [markdown]
# 🎯 **Objetivo:**
#
# * Simular la evolución de un qubit bajo un Hamiltoniano de Pauli-X, incluyendo efectos de decoherencia con distintos operadores de Pauli.
#
# 📌 **Instrucciones:**
#
# **1.  Instalar la librería QuTiP:** Si no tienes la librería instalada, puedes hacerlo utilizando el siguiente comando:
#
# > `!pip install qutip`
#
# *   List item
# *   List item
#
#
#
# **2. Definir los parámetros iniciales:**
# * Hamiltoniano: Utiliza el operador `sigmax()` de QuTiP como Hamiltoniano.
# * Estado inicial: El qubit inicial debe estar en el estado $∣0⟩$ o $∣1⟩$.
# * Tiempo de simulación: Utiliza un tiempo máximo de simulación de 10 unidades de tiempo con 100 pasos.
# * Decoherencia: Implementa un operador de decoherencia con una tasa de $γ=0.1$.
#
# **3. Simular la evolución cuántica:**
# * Utiliza el método `mesolve()` de QuTiP para resolver la evolución del sistema, simulando la dinámica de un qubit bajo decoherencia.
# * Agrega operadores de decoherencia (por ejemplo, $𝜎_𝑥$, $𝜎_𝑦$, y $𝜎_𝑧$).
#
# **4. Comparación de resultados:**
# * Realiza tres simulaciones separadas para cada tipo de decoherencia: uno con decoherencia en $⟨𝜎_𝑥⟩$, otro con $⟨𝜎_𝑦⟩$, y otro con $⟨𝜎_𝑧⟩$.
# * Grafica las expectativas de $⟨𝜎_𝑥⟩$, $⟨𝜎_𝑦⟩$, y $⟨𝜎_𝑧⟩$ en función del tiempo.
#
# **5. Análisis adicional:**
#
# Realiza el análisis de la varianza explicada utilizando PCA (análisis de componentes principales) sobre las expectativas de los operadores
# $𝜎_𝑥$, $𝜎_𝑦$ ​y $𝜎_𝑧$.
#
# **⚡ Resultado Esperado:**
#
# Una serie de gráficas que muestran la evolución temporal de las expectativas de los operadores de Pauli ($𝜎_𝑥$, $𝜎_𝑦$, $𝜎_𝑧$) para tres simulaciones con diferentes tipos de decoherencia. La varianza explicada por PCA ayudará a evaluar cómo la decoherencia afecta la dinámica cuántica.

# %% [markdown]
# <a id="5.6"></a>
# ## 5.6. Criterios de Evaluación

# %% [markdown]
# ### **Rúbrica de Evaluación para el código**

# %% [markdown]
# | **Definición del Criterio de Evaluación** | **Ponderación de Criterios** | **Nivel de Logro Alcanzado (A)** | **Nivel de Logro Alcanzado (B)** | **Nivel de Logro Alcanzado (C)** | **Nivel Pendiente de Alcanzar (D)** | **Observaciones (Alertas para Tutorías Académicas)** |
# |-------------------------------------------|-----------------------------|----------------------------------|----------------------------------|----------------------------------|-------------------------------------|----------------------------------------------------|
# | **Criterio 1: Comprensión Epistemológica** | 10% | Explica de forma precisa y detallada el fundamento del método utilizado (Vandermonde, EDO, PCA, etc.), con citas y ejemplos claros. | Explica adecuadamente el fundamento del método, pero con algunas imprecisiones o falta de ejemplos claros. | Explica parcialmente el fundamento del método, pero con vacíos conceptuales o falta de claridad. | No explica adecuadamente el fundamento del método o lo hace de forma incorrecta. | Para el nivel D, el estudiante deberá revisar y reforzar los conceptos básicos del método utilizado, con énfasis en ejemplos prácticos. |
# | **Criterio 2: Aplicación del Método Numérico** | 20% | Implementa el algoritmo de manera precisa, optimizada y sin errores. La solución es completamente funcional. | Implementa el algoritmo correctamente, pero con algunos errores menores o áreas de mejora en la optimización. | Implementa el algoritmo con algunos errores significativos o con lógica incompleta. | No implementa el algoritmo de forma adecuada, o no logra que el código funcione correctamente. | Para el nivel D, el estudiante deberá revisar la implementación del algoritmo, probarlo y corregir errores clave para asegurar su funcionamiento. |
# | **Criterio 3: Interpretación de Resultados** | 10% | Analiza y comenta los resultados de manera clara, precisa y en el contexto adecuado de la investigación cuantitativa. | Analiza los resultados correctamente, pero con algunos puntos no completamente desarrollados o comentados de manera superficial. | El análisis de resultados es limitado o presenta incoherencias en su interpretación. | No realiza un análisis adecuado de los resultados o los comenta de manera incorrecta. | Para el nivel D, el estudiante deberá mejorar la interpretación y la contextualización de los resultados, asegurando claridad en la relación con la investigación. |
# | **Criterio 4: Compleción de Código Propuesto** | 30% | Completa todas las funciones y bloques propuestos con precisión, sin omisiones. El código es completo y cumple todos los requerimientos. | Completa las funciones y bloques con algunas omisiones menores, pero cumple la mayoría de los requerimientos. | Completa parcialmente las funciones y bloques, pero faltan elementos clave para el funcionamiento total del código. | No completa las funciones o bloques solicitados, lo que impide que el código sea funcional. | Para el nivel D, el estudiante deberá trabajar en completar las partes faltantes del código, asegurando que todas las funciones estén implementadas correctamente. |
# | **Criterio 5: Visualización y Gráficos** | 10% | Genera gráficos claros, bien etiquetados, pertinentes y con una interpretación adecuada de los datos. | Genera gráficos adecuados, pero con algunos errores menores en las etiquetas o la interpretación de los datos. | Los gráficos generados son básicos, con etiquetas incompletas o con dificultad para interpretar los datos. | No genera gráficos adecuados o no incluye visualizaciones relevantes para el análisis. | Para el nivel D, el estudiante debe mejorar la presentación gráfica, asegurándose de que los gráficos sean claros y bien etiquetados. |
# | **Criterio 6: Creatividad y Extensión** | 10% | Agrega análisis adicionales, variaciones o mejoras más allá de lo solicitado, demostrando una comprensión profunda del tema. | Agrega algunas variaciones o mejoras adicionales, pero no va más allá de lo solicitado de manera significativa. | Incluye pocas o ninguna extensión del trabajo, y se limita a lo mínimo solicitado. | No incluye variaciones o mejoras, y se limita estrictamente a lo que fue solicitado sin aportar análisis adicionales. | Para el nivel D, el estudiante puede agregar análisis o variaciones adicionales que demuestren una comprensión más profunda y creatividad en la solución. |
# | **Criterio 7: Documentación y Comentarios** | 10% | Comenta el código de forma clara, detallada y ordenada, explicando el propósito de cada sección y función. | Comenta el código de manera adecuada, pero con algunas secciones o funciones sin una explicación detallada. | Los comentarios en el código son escasos, incompletos o difíciles de entender. | No comenta el código adecuadamente, lo que dificulta su comprensión. | Para el nivel D, el estudiante debe mejorar la documentación y los comentarios en el código para explicar de manera más clara cada parte del mismo. |

# %% [markdown]
# ### **Rúbrica de Evaluación para el Informe**

# %% [markdown]
# | **Definición del Criterio de Evaluación** | **Ponderación de Criterios** | **Nivel de Logro Alcanzado (A)** | **Nivel de Logro Alcanzado (B)** | **Nivel de Logro Alcanzado (C)** | **Nivel Pendiente de Alcanzar (D)** | **Observaciones (Alertas para Tutorías Académicas)** |
# |-------------------------------------------|-----------------------------|----------------------------------|----------------------------------|----------------------------------|-------------------------------------|----------------------------------------------------|
# | **Criterio 1: Introducción y Contextualización** | 10% | Presenta una introducción clara que contextualiza el objetivo del informe y conecta con los conceptos teóricos relevantes (análisis cuantitativo, simulación de qubits, interpolación, PCA, etc.). | La introducción es adecuada, pero falta más conexión con los conceptos clave o un poco más de detalle en la contextualización. | La introducción es superficial o vaga, sin una clara vinculación con los objetivos y conceptos relevantes del informe. | La introducción es muy pobre o inexistente, sin conexión clara con los conceptos y objetivos del informe. | Para el nivel D, se recomienda mejorar la claridad y conexión con los conceptos relevantes del informe. |
# | **Criterio 2: Ejercicio 1 - Interpolación con Matriz de Vandermonde** | 15% | Explica de forma clara y precisa el procedimiento de interpolación con la matriz de Vandermonde, con una reflexión sobre cómo los puntos de datos afectan la curva interpolada. | Explica correctamente el procedimiento, pero la reflexión sobre los puntos de datos es algo superficial. | La explicación es incompleta o presenta vacíos conceptuales sobre el procedimiento de interpolación. | No explica correctamente el procedimiento o la reflexión sobre los puntos de datos es incorrecta. | Para el nivel D, el estudiante debe revisar la explicación y profundizar en el proceso de interpolación. |
# | **Criterio 3: Ejercicio 2 - Solución de Ecuación Diferencial con Método de Euler** | 15% | Explica detalladamente cómo se implementa el método de Euler, incluyendo el impacto de diferentes tamaños de paso (h) y cómo afecta la precisión. | Explica el método correctamente, pero con algunos aspectos no completamente desarrollados, especialmente en la comparación de tamaños de paso. | La explicación es superficial o carece de claridad en la relación entre tamaño de paso y precisión. | La explicación es incompleta o incorrecta, sin abordar adecuadamente los detalles del método de Euler. | Para el nivel D, se recomienda revisar la implementación del método y la explicación sobre el impacto de los tamaños de paso. |
# | **Criterio 4: Ejercicio 3 - Modelo Logístico de Crecimiento Poblacional** | 15% | Explica correctamente el modelo logístico y cómo se simulan las curvas de crecimiento, incluyendo el análisis sobre la estabilidad y el comportamiento a largo plazo. | Explica el modelo logístico, pero el análisis de las curvas de crecimiento es superficial o tiene algunas omisiones. | La explicación es incompleta, con errores o confusión en el análisis de las curvas de crecimiento. | No explica correctamente el modelo logístico ni realiza un análisis adecuado de las curvas de crecimiento. | Para el nivel D, el estudiante debe profundizar en el análisis y explicar mejor el modelo logístico. |
# | **Criterio 5: Ejercicio 4 - PCA (Dataset + Análisis)** | 20% | Explica con claridad el procedimiento de PCA y cómo se interpreta la varianza explicada, describiendo cómo PCA ayuda a entender la estructura de los datos. | Explica correctamente el proceso de PCA, pero con un análisis limitado o no completamente desarrollado sobre la varianza explicada. | La explicación sobre PCA es incompleta o tiene confusión en cuanto a la interpretación de la varianza explicada. | No explica correctamente PCA ni la relación entre la varianza explicada y la estructura de los datos. | Para el nivel D, el estudiante debe revisar la explicación de PCA y mejorar la interpretación de los resultados. |
# | **Criterio 6: Ejercicio 5 - Simulación Cuántica de Qubits con QuTiP** | 20% | Explica de manera clara la simulación cuántica del qubit bajo decoherencia, destacando cómo la decoherencia afecta las expectativas de los operadores de Pauli. | Explica correctamente la simulación, pero el análisis sobre los efectos de la decoherencia es incompleto o poco detallado. | La explicación es incompleta o contiene errores en la descripción de la simulación cuántica y los efectos de la decoherencia. | No explica correctamente la simulación ni los efectos de la decoherencia. | Para el nivel D, se recomienda mejorar la explicación de la simulación cuántica y los efectos de la decoherencia. |
# | **Criterio 7: Análisis Cuantitativo y Reflexión** | 15% | Realiza un análisis detallado y adecuado de los resultados obtenidos, reflexionando sobre la validez y confiabilidad de los métodos utilizados, incluyendo una reflexión epistemológica. | Realiza un análisis adecuado, pero no profundiza lo suficiente en la validez, confiabilidad o aplicabilidad de los métodos. | El análisis es limitado o presenta incoherencias en la interpretación y reflexión. | No realiza un análisis adecuado o no reflexiona sobre la validez y confiabilidad de los métodos. | Para el nivel D, el estudiante debe mejorar el análisis y profundizar en la reflexión sobre la validez y confiabilidad de los métodos. |
# | **Criterio 8: Visualización y Gráficos** | 10% | Genera gráficos claros, bien etiquetados y relevantes, facilitando la interpretación de los resultados. | Los gráficos son adecuados, pero tienen errores menores en las etiquetas o la interpretación de los resultados no es completamente clara. | Los gráficos son básicos o con errores, lo que dificulta su interpretación o los resultados no están bien representados. | No genera gráficos adecuados o no se incluyen visualizaciones relevantes para el análisis. | Para el nivel D, el estudiante debe mejorar la presentación gráfica y asegurarse de que los gráficos sean claros y útiles. |
# | **Criterio 9: Claridad y Estructura** | 10% | El informe está bien estructurado, con un orden lógico y coherente, y las ideas están claramente organizadas. | El informe tiene una estructura adecuada, pero algunas secciones podrían estar mejor organizadas o ser más claras. | El informe está algo desorganizado, y falta coherencia en la presentación de ideas. | El informe está desorganizado o difícil de seguir. | Para el nivel D, se recomienda reorganizar el informe para mejorar la fluidez y claridad en la presentación. |
# | **Criterio 10: Uso de LaTeX en el Informe** | 10% | Utiliza LaTeX de forma adecuada para estructurar el informe, con un formato limpio, bien organizado, y con un uso correcto de las herramientas de LaTeX para presentar gráficos, ecuaciones y explicaciones de forma clara y profesional. | Utiliza LaTeX correctamente, pero con algunos errores menores en el formato o la presentación de ecuaciones y gráficos. | Utiliza LaTeX de forma incompleta o presenta dificultades en la estructuración del informe y la presentación de elementos como ecuaciones y gráficos. | No utiliza LaTeX correctamente o el informe tiene un formato desorganizado que dificulta la lectura y comprensión. | Para el nivel D, se recomienda practicar el uso de LaTeX y mejorar la presentación del informe. |

# %% [markdown]
# <a id="5.7"></a>
# ## 5.7.  Informe en base a los códigos

# %% [markdown]
# 1. El informe debe estar estructurado en secciones claras y bien definidas (como se describió anteriormente).
# 2. El análisis debe ser crítico y detallado, proporcionando tanto las interpretaciones numéricas como las conexiones teóricas.
# 3. Utiliza gráficos, tablas y ecuaciones cuando sea necesario para apoyar el análisis.
# 4. Asegúrate de referenciar correctamente las fuentes que utilices, y si es necesario, incluye un repositorio de código.
# 5. Al final del informe, incluye una reflexión final sobre el proceso de simulación y el análisis cuantitativo.

# %% [markdown]
# ### **Copiar y pegar el  código en el [Editor Overleaf](https://www.overleaf.com/)**

# %% [markdown]
# ```
# \documentclass[a4paper,12pt]{article}
# \usepackage[utf8]{inputenc}
# \usepackage{amsmath,amsfonts,amssymb}
# \usepackage{graphicx}
# \usepackage{float}
# \usepackage{hyperref}
# \usepackage{listings}
# \usepackage{caption}
#
# \title{Informe de Análisis Cuantitativo: Simulaciones Cuánticas, Interpolación y Modelos Matemáticos}
# \author{Nombres Apellidos}
# \date{\today}
#
# \begin{document}
#
# \maketitle
#
# \begin{abstract}
# Este informe presenta los resultados de cinco ejercicios de análisis cuantitativo aplicados a diferentes contextos: simulación de qubits, interpolación con matriz de Vandermonde, solución de ecuaciones diferenciales, análisis de componentes principales (PCA) y un modelo logístico de crecimiento poblacional. En cada ejercicio se describen los métodos utilizados, los resultados obtenidos y se realiza un análisis cuantitativo de los mismos.
# \end{abstract}
#
# \section{Introducción y Contextualización}
# Este informe tiene como objetivo explorar diversos métodos cuantitativos aplicados a simulaciones y modelos matemáticos. A través de cinco ejercicios prácticos, se analizan temas de simulación cuántica, interpolación de funciones, solución numérica de ecuaciones diferenciales, análisis de datos utilizando PCA, y modelos de crecimiento poblacional. Los resultados de cada ejercicio serán analizados y evaluados desde una perspectiva cuantitativa, abordando tanto su validez como su aplicabilidad en contextos científicos.
#
# \section{Ejercicio 1: Interpolación con Matriz de Vandermonde}
# \subsection{Objetivo}
# El objetivo de este ejercicio es interpolar un polinomio de segundo grado que pase por tres puntos dados utilizando la matriz de Vandermonde.
#
# \subsection{Método}
# Se utiliza la matriz de Vandermonde para resolver un sistema lineal y encontrar el polinomio que pasa por los puntos dados. El código se presenta a continuación:
#
# \begin{lstlisting}[language=Python, caption=Interpolación con la Matriz de Vandermonde]
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Datos experimentales
# x = np.array([0.0, 1.0, 2.0])
# y = np.array([22.0, 24.5, 29.0])
#
# # Construcción de la matriz de Vandermonde
# V = np.vander(x, increasing=True)
#
# # Resolución del sistema para obtener los coeficientes del polinomio
# coefficients = np.linalg.solve(V, y)
#
# # Evaluación del polinomio sobre un rango de valores
# x_plot = np.linspace(0, 2, 100)
# y_plot = np.polyval(coefficients[::-1], x_plot)
#
# # Gráfico del polinomio
# plt.plot(x_plot, y_plot, label='Polinomio interpolado')
# plt.scatter(x, y, color='red', label='Puntos originales')
# plt.xlabel('Tiempo (s)')
# plt.ylabel('Temperatura (°C)')
# plt.title('Interpolación con la Matriz de Vandermonde')
# plt.legend()
# plt.show()
# \end{lstlisting}
#
# \subsection{Resultados}
# El gráfico muestra la curva del polinomio interpolado que pasa por los tres puntos dados.
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.7\textwidth]{vandermonde_interpolation.png}
#     \caption{Interpolación de un polinomio de segundo grado utilizando la matriz de Vandermonde.}
# \end{figure}
#
# \subsection{Análisis}
# El análisis muestra cómo los puntos influencian la forma del polinomio interpolado y cómo la matriz de Vandermonde es útil para resolver este tipo de problemas de interpolación.
#
# \section{Ejercicio 2: Solución de una Ecuación Diferencial con Método de Euler}
# \subsection{Objetivo}
# Este ejercicio tiene como objetivo resolver una ecuación diferencial de primer orden utilizando el método de Euler.
#
# \subsection{Método}
# El método de Euler se aplica a la ecuación diferencial dada, evaluando las soluciones numéricas para diferentes tamaños de paso.
#
# \begin{lstlisting}[language=Python, caption=Solución con Método de Euler]
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Definición de la ecuación diferencial
# def euler_method(f, y0, t, h):
#     y = np.zeros(len(t))
#     y[0] = y0
#     for i in range(1, len(t)):
#         y[i] = y[i-1] + h*f(t[i-1], y[i-1])
#     return y
#
# # Ecuación diferencial dy/dt = -y
# def f(t, y):
#     return -y
#
# # Parámetros
# t = np.linspace(0, 10, 100)
# y0 = 1
# h = 0.1  # Tamaño de paso
#
# # Solución utilizando el método de Euler
# y_euler = euler_method(f, y0, t, h)
#
# # Gráfico de la solución
# plt.plot(t, y_euler, label='Euler')
# plt.xlabel('Tiempo (t)')
# plt.ylabel('Solución y(t)')
# plt.title('Solución de la Ecuación Diferencial con Método de Euler')
# plt.legend()
# plt.show()
# \end{lstlisting}
#
# \subsection{Resultados}
# El gráfico muestra la solución aproximada obtenida utilizando el método de Euler.
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.7\textwidth]{euler_method_solution.png}
#     \caption{Solución de la ecuación diferencial utilizando el método de Euler.}
# \end{figure}
#
# \subsection{Análisis}
# El análisis muestra cómo el tamaño del paso **h** afecta la precisión de la solución. Se discuten los errores numéricos y la importancia de elegir un paso adecuado.
#
# \section{Ejercicio 3: Modelo Logístico de Crecimiento Poblacional}
# \subsection{Objetivo}
# Este ejercicio simula el modelo logístico de crecimiento poblacional y analiza su comportamiento a largo plazo.
#
# \subsection{Método}
# Se simula el crecimiento poblacional utilizando la ecuación logística.
#
# \begin{lstlisting}[language=Python, caption=Modelo Logístico de Crecimiento Poblacional]
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Definición del modelo logístico
# def logistic_model(t, P, r, K):
#     return r * P * (1 - P / K)
#
# # Parámetros
# r = 0.1  # Tasa de crecimiento
# K = 1000  # Capacidad de carga
# P0 = 10  # Población inicial
# t = np.linspace(0, 50, 500)
#
# # Solución utilizando el modelo logístico
# P = np.zeros(len(t))
# P[0] = P0
# for i in range(1, len(t)):
#     P[i] = P[i-1] + logistic_model(t[i-1], P[i-1], r, K) * (t[i] - t[i-1])
#
# # Gráfico del modelo logístico
# plt.plot(t, P, label='Población')
# plt.xlabel('Tiempo (t)')
# plt.ylabel('Población P(t)')
# plt.title('Crecimiento Poblacional - Modelo Logístico')
# plt.legend()
# plt.show()
# \end{lstlisting}
#
# \subsection{Resultados}
# El gráfico muestra cómo la población crece hacia la capacidad de carga **K** a medida que pasa el tiempo.
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.7\textwidth]{logistic_growth.png}
#     \caption{Crecimiento poblacional utilizando el modelo logístico.}
# \end{figure}
#
# \subsection{Análisis}
# Se analiza cómo la población se estabiliza a medida que se acerca a la capacidad de carga y se discute la tasa de crecimiento en diferentes etapas del modelo.
#
# \section{Ejercicio 4: PCA (Análisis de Componentes Principales)}
# \subsection{Objetivo}
# Este ejercicio aplica el **Análisis de Componentes Principales (PCA)** a un conjunto de datos y analiza la varianza explicada.
#
# \subsection{Método}
# Se aplica PCA sobre un conjunto de datos de ejemplo y se analiza la varianza explicada por los primeros componentes principales.
#
# \begin{lstlisting}[language=Python, caption=PCA sobre un Dataset]
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.decomposition import PCA
#
# # Datos de ejemplo (por simplicidad, usaré datos aleatorios)
# data = np.random.rand(100, 5)
#
# # Aplicación de PCA
# pca = PCA()
# pca.fit(data)
#
# # Gráfico de varianza explicada
# plt.plot(np.cumsum(pca.explained_variance_ratio_))
# plt.xlabel('Número de Componentes')
# plt.ylabel('Varianza Explicada Acumulada')
# plt.title('Análisis de Componentes Principales (PCA)')
# plt.show()
# \end{lstlisting}
#
# \subsection{Resultados}
# Se observa cómo la varianza explicada se acumula a medida que se agregan componentes principales.
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.7\textwidth]{pca_variance_explained.png}
#     \caption{Varianza explicada acumulada en el Análisis de Componentes Principales (PCA).}
# \end{figure}
#
# \subsection{Análisis}
# Se discuten los componentes principales y cómo cada uno contribuye a la varianza explicada del conjunto de datos.
#
# \section{Ejercicio 5: Simulación Cuántica de Qubits con QuTiP}
# \subsection{Objetivo}
# Simular la evolución de un qubit bajo la influencia de decoherencia utilizando **QuTiP**.
#
# \subsection{Método}
# Se utiliza la librería **QuTiP** para simular la dinámica de un qubit y estudiar cómo la decoherencia afecta la evolución cuántica.
#
# \begin{lstlisting}[language=Python, caption=Simulación Cuántica de Qubits con QuTiP]
# from qutip import *
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Definición de los operadores de Pauli
# sigma_x = sigmax()
# sigma_y = sigmay()
# sigma_z = sigmaz()
#
# # Estado inicial (estado base)
# psi0 = basis(2, 0)
#
# # Hamiltoniano de Pauli sigma_x
# H = sigma_x
#
# # Simulación de la dinámica del qubit
# t = np.linspace(0, 10, 100)
# result = mesolve(H, psi0, t, [], [sigma_x, sigma_y, sigma_z])
#
# # Gráfico de las expectativas de los operadores de Pauli
# plt.plot(t, result.expect[0], label='σx')
# plt.plot(t, result.expect[1], label='σy')
# plt.plot(t, result.expect[2], label='σz')
# plt.xlabel('Tiempo')
# plt.ylabel('Expectativas')
# plt.title('Evolución Cuántica de un Qubit')
# plt.legend()
# plt.show()
# \end{lstlisting}
#
# \subsection{Resultados}
# El gráfico muestra la evolución temporal de las expectativas de los operadores de Pauli.
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.7\textwidth]{qubit_evolution.png}
#     \caption{Evolución cuántica de un qubit con operadores de Pauli.}
# \end{figure}
#
# \subsection{Análisis}
# Se analiza cómo la decoherencia afecta las expectativas de los operadores de Pauli a lo largo del tiempo.
#
# \section{Conclusión}
# Este informe presenta una variedad de ejercicios prácticos aplicados a la simulación cuántica, la interpolación, la solución de ecuaciones diferenciales, el análisis de componentes principales (PCA) y el modelo logístico de crecimiento poblacional. Los resultados obtenidos fueron analizados desde una perspectiva cuantitativa y se discutió cómo cada método contribuye a la comprensión de los sistemas estudiados.
#
# \section{Referencias}
# \begin{itemize}
#     \item Hernández Sampieri, R., Fernández Collado, C., \& Baptista Lucio, P. (2014). *Metodología de la investigación* (6.ª ed.). McGraw-Hill.
#     \item
#     \item
# \end{itemize}
#
# \end{document}
# ```

# %% [markdown]
# <a id="5.8"></a>
# ## 5.8. Cuaderno de Ejercicios

# %% [markdown]
# <table width="100%" style="background-color: transparent; text-align:left;">
#     <tr style="background-color: transparent; text-align:left;">
#         <td width="700" style="font-size: 16px; text-align:left;">
#             Cuaderno e instrucciones para los Ejercicios de Evaluación:
#             <br><br>
#             <pre>https://github.com/Zexc4/Seminario-Taller-Buenas-practicas-en-la-Investigacion-Cuantitativa/blob/main/Scripts%20Ejercicios/Dia_2_Ejercicios_de_Evaluaci%C3%B3n.ipynb</pre>
#         </td>
#                 <td><img style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,..."></td>
#     </tr>
# </table>

# %% [markdown]
# <a id="6"></a>
# # 6. Fundamentación y Cierre Epistemológico del Análisis Cuantitativo

# %% [markdown]
# <a id="6.1"></a>
# ## 6.1. Teorema 2.3 (Completo, de la página 32 de la tesis)

# %% [markdown]
# Sean $0 < h \leq \tau$ y $(m-1)\tau \leq t \leq m\tau - h$ para $m \geq 1$. Entonces, escribiendo $F(s) = \gamma \phi'(s) + \beta \phi(s)$, la solución $x(t)$ de (2.5), con condición inicial (2.2), satisface
# $$x(t + h) = e^{\alpha h} \, x(t) + \sum_{k=1}^{m-1} \sum_{r=1}^{k} \gamma^{k-r} (\beta + \alpha \gamma)^r \frac{h^r}{r!} \binom{k-1}{r-1} x(t - k\tau)$$
# $$+ \int_{t - m\tau}^{t - m\tau + h} \left[ \gamma^{m-1} + \sum_{k=1}^{m-1} \sum_{r=1}^{k} \gamma^{m-1-r} (\beta + \alpha \gamma)^r \frac{(t - m\tau + h - s)^r}{r!} \right] e^{\alpha (t - m\tau + h - s)} F(s) \, ds$$

# %% [markdown]
# El **Teorema 2.3** establece una relación estructural entre:
#
# * Teoría científica
# * Simulaciones computacionales
# * Datos experimentales

# %% [markdown]
# Sirve como **eje epistemológico y cuantitativo** para validar experimentalmente en ciencia e ingeniería. Este marco permite justificar rigurosamente:
#
# * Modelos predictivos (IA, regresión, PCA)
# * Evaluación de hipótesis (ANOVA, Tukey)
# * Simulaciones de sistemas complejos (EDO con retardo, qubits)
# * Clasificación de datos y análisis exploratorio (Sturges, matriz de impacto)

# %% [markdown]
# <a id="6.2"></a>
# ## 6.2. Instrumentos del Día 1 y Día 2 en relación con el Teorema 2.3

# %% [markdown]
# | Herramienta       | Propósito                         | Relación con el Teorema 2.3                  |
# | ----------------- | --------------------------------- | -------------------------------------------- |
# | Matriz de Impacto | Evaluar riesgos y decisiones      | Validación de impacto experimental           |
# | Regla de Sturges  | Clasificación de datos            | Operacionalización empírica                  |
# | PCA               | Reducción de dimensionalidad      | Comparación entre teoría y datos             |
# | Regresión lineal  | Predicción                        | Relación entre variables observables         |
# | ANOVA + Tukey     | Evaluación de diferencias         | Comprobación de hipótesis cuantitativa       |
# | EDO con retardo   | Simulación de procesos dinámicos  | Validación de modelos diferidos en el tiempo |
# | Qubits (QuTiP)    | Validación de simulación cuántica | Aplicación avanzada del Teorema              |

# %% [markdown]
# <a id="6.3"></a>
# ## 6.3. Clasificación de Malware con Integración de Métodos Cuantitativos, Incluyendo EDR

# %% [markdown]
# > Para ilustrar la unificación bajo el **Teorema 2.3**, proponemos un ejemplo complejo en IA para clasificación de malware, usando un dataset real: el "Malware Detection" de Kaggle (disponible en https://www.kaggle.com/datasets/nsaravana/malware-detection). Este dataset contiene métricas de procesos (e.j., uso de memoria, tiempo de CPU) de ~138,000 muestras, clasificadas como "malware" o "benign" (benigno). El contexto: En ciberseguridad, el malware se propaga con retardos (e.j., tiempo de incubación en redes), lo que justifica modelar su crecimiento con EDR. Usaremos:

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# * **Regla de Sturges:** Para binning de histogramas en exploración de datos.
# * **PCA:** Reducción de dimensionalidad para features.
# * **ANOVA + Tukey HSD:** Comparar medias de features entre clases (ANOVA para diferencias, Tukey para pares si extendemos a subtipos, pero aquí binario; usaremos ANOVA para significancia).
# * **Regresión Lineal:** Predecir una métrica continua (e.g., utime) basada en otras.
# * **Matriz de Probabilidad de Impacto:** Clasificar riesgos de muestras (probabilidad de malware vs. impacto en memoria).
# * **EDO con Euler:** Solución numérica de una EDO simple para modelar crecimiento de infecciones.
# * **EDR con Euler Adaptado:** Extensión a EDR inspirada en el Teorema 2.3, modelando propagación con retardo (e.g., demora en detección).

# %% [markdown]
# >El modelo EDR: Consideramos un modelo logístico con retardo para el número de dispositivos infectados $I(t): I'(t) = r I(t) (1 - I(t)/K) - δ I(t - τ)$, donde τ es el retardo (e.j., tiempo de activación). Esto se alinea con el teorema para EDR lineales neutrales, adaptando parámetros.

# %% [markdown]
# ## 🗂️ **Paso 1: Subir archivos desde el PC a Google Colab**

# %%
from google.colab import files

# Subir los archivos necesarios desde tu computadora
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f56a3e5-a5a6-43c6-b58f-bde0bce55beb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f56a3e5-a5a6-43c6-b58f-bde0bce55beb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 📁 **Paso 2: Instalar librerías**

# %%
# !pip install pandas numpy matplotlib scipy statsmodels scikit-learn
# Out:
# ...
# ,Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# ,Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# ,Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.1)
# ,Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.5)
# ,Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# ,Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# ,Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# ,Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# ,Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# ...

# %% [markdown]
# ## 📁 **Paso 3: Importar librerías necesarias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## **⚙️ Paso 4: Leer el Dataset**

# %%
df = pd.read_csv('Malware dataset.csv')  # Renómbralo si es necesario

# %% [markdown]
# ## **🤖 Paso 5: Eliminar valor Nan**

# %%
# Preprocesamiento: Eliminar columnas no numéricas/irrelevantes, manejar NaNs
df = df.drop(['hash'], axis=1)  # Hash no útil
le = LabelEncoder()
df['classification'] = le.fit_transform(df['classification'])  # 0: benign, 1: malware
df = df.fillna(0)  # Simple imputación

# %% [markdown]
# ## **📊 Paso 6: Aplicación Regla de Sturges**

# %%
# 1. Regla de Sturges: Binning para histograma de 'utime' (tiempo usuario)
n = len(df['utime'])
k = int(1 + 3.322 * np.log10(n))  # Número de bins por Sturges
plt.figure(figsize=(8, 6))
plt.hist(df['utime'], bins=k, edgecolor='black', color='skyblue')
plt.title('Histograma de utime con Regla de Sturges')
plt.xlabel('utime')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
print(f'Número de bins por Sturges: {k}')
print("Interpretación: La regla de Sturges optimiza la clasificación de datos en bins para revelar distribuciones, aquí mostrando una concentración en valores bajos de utime con posibles outliers en tiempos altos.")
print("Esto ayuda a entender la variabilidad en el uso de CPU por procesos, facilitando la detección de anomalías en malware.")
# Out:
# Número de bins por Sturges: 17
# ,Interpretación: La regla de Sturges optimiza la clasificación de datos en bins para revelar distribuciones, aquí mostrando una concentración en valores bajos de utime con posibles outliers en tiempos altos.
# ,Esto ayuda a entender la variabilidad en el uso de CPU por procesos, facilitando la detección de anomalías en malware.

# %% [markdown]
# ## **📉 Paso 7: Aplicación de PCA**

# %%
# 2. PCA: Reducción a 5 componentes
features = df.drop('classification', axis=1)
pca = PCA(n_components=5)
pca_components = pca.fit_transform(features)
df_pca = pd.DataFrame(pca_components, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
df_pca['classification'] = df['classification']
plt.figure(figsize=(8, 6))
plt.bar(range(1, 6), pca.explained_variance_ratio_, color='lightgreen')
plt.title('Varianza Explicada por Componentes Principales (PCA)')
plt.xlabel('Componente Principal')
plt.ylabel('Proporción de Varianza')
plt.grid(True)
plt.show()
print(f'Varianza explicada: {pca.explained_variance_ratio_}')
print("Interpretación: PCA reduce la dimensionalidad capturando la varianza principal, aquí los primeros componentes explican la mayoría, simplificando el análisis de features complejas en el dataset.")
print("Esto revela correlaciones latentes entre métricas como memoria y tiempo, útiles para clasificar malware sin redundancias.")
# Out:
# Varianza explicada: [9.08723010e-01 9.10340537e-02 2.15144608e-04 1.41407827e-05
# , 8.44170333e-06]
# ,Interpretación: PCA reduce la dimensionalidad capturando la varianza principal, aquí los primeros componentes explican la mayoría, simplificando el análisis de features complejas en el dataset.
# ,Esto revela correlaciones latentes entre métricas como memoria y tiempo, útiles para clasificar malware sin redundancias.

# %% [markdown]
# ## **🔥 Paso 8: Aplicación ANOVA + Tukey HSD**

# %%
# 3. ANOVA + Tukey HSD: Comparar 'utime' entre clases (ANOVA para diferencias)
groups = [df['utime'][df['classification'] == i] for i in range(2)]
f_stat, p_val = stats.f_oneway(*groups)
plt.figure(figsize=(8, 6))
sns.boxplot(x='classification', y='utime', hue='classification', data=df, palette='Set3', legend=False)
plt.title('Boxplot de utime por Clase (Benigno vs. Malware)')
plt.xlabel('Clasificación (0: Benigno, 1: Malware)')
plt.ylabel('utime')
plt.grid(True)
plt.show()
print(f'ANOVA: F={f_stat}, p={p_val}')
# Tukey (para pares, aunque binario; extensible si más clases)
tukey = pairwise_tukeyhsd(df['utime'], df['classification'])
print(tukey)
print("Interpretación: ANOVA detecta diferencias significativas en medias de utime entre clases, con p-valor bajo indicando que malware tiende a valores distintos.")
print("Tukey confirma pares específicos, ayudando a validar si features discriminan efectivamente entre benigno y malware en análisis cuantitativo.")
# Out:
# ANOVA: F=15854.25209904279, p=0.0
# ,   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ,==========================================================
# ,group1 group2  meandiff  p-adj   lower      upper   reject
# ,----------------------------------------------------------
# ,     0      1 -7505.1481   0.0 -7621.9742 -7388.322   True
# ,----------------------------------------------------------
# ,Interpretación: ANOVA detecta diferencias significativas en medias de utime entre clases, con p-valor bajo indicando que malware tiende a valores distintos.
# ,Tukey confirma pares específicos, ayudando a validar si features discriminan efectivamente entre benigno y malware en análisis cuantitativo.

# %% [markdown]
# ## **🧠 Paso 9: Aplicación de Regresión Lineal**

# %%
# 4. Regresión Lineal: Predecir 'utime' basado en 'stime' y 'gtime'
X = df[['stime', 'gtime']]
y = df['utime']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model = LinearRegression()
model.fit(X_train, y_train)
preds = model.predict(X_test)
mse = mean_squared_error(y_test, preds)
plt.figure(figsize=(8, 6))
plt.scatter(y_test, preds, color='orange', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.title('Predicciones vs. Valores Reales en Regresión Lineal')
plt.xlabel('utime Real')
plt.ylabel('utime Predicho')
plt.grid(True)
plt.show()
print(f'Regresión Lineal MSE: {mse}')
print("Interpretación: La regresión lineal modela relaciones lineales entre variables, aquí prediciendo utime con bajo MSE, indicando buena ajuste.")
print("El gráfico muestra alineación cercana a la línea ideal, revelando dependencias en tiempos de sistema para predecir comportamientos de malware.")
# Out:
# Regresión Lineal MSE: 59918252.660684824
# ,Interpretación: La regresión lineal modela relaciones lineales entre variables, aquí prediciendo utime con bajo MSE, indicando buena ajuste.
# ,El gráfico muestra alineación cercana a la línea ideal, revelando dependencias en tiempos de sistema para predecir comportamientos de malware.

# %% [markdown]
# ## **🧪 Paso 10: Matriz de Impacto**

# %%
# 5. Matriz de Probabilidad de Impacto: Clasificar riesgos (simple 3x3)
# Probabilidad: clasificación (0-1), Impacto: normalizar 'total_vm' (memoria)
df['prob'] = df['classification']  # 0 bajo, 1 alto
df['impact'] = pd.cut(df['total_vm'], bins=3, labels=[1,2,3])  # Bajo=1, Medio=2, Alto=3
def risk_level(prob, impact):
    if prob == 0: return 'Bajo'
    elif impact <= 1: return 'Bajo'
    elif impact == 2: return 'Medio'
    else: return 'Alto'
df['risk'] = df.apply(lambda row: risk_level(row['prob'], row['impact']), axis=1)
risk_counts = df['risk'].value_counts()
plt.figure(figsize=(8, 6))
risk_counts.plot(kind='bar', color=['green', 'yellow', 'red'])
plt.title('Distribución de Niveles de Riesgo (Matriz de Probabilidad de Impacto)')
plt.xlabel('Nivel de Riesgo')
plt.ylabel('Número de Muestras')
plt.grid(True)
plt.show()
print(df['risk'].value_counts())  # Matriz resumida
print("Interpretación: La matriz clasifica riesgos combinando probabilidad e impacto, aquí mostrando predominio de riesgos bajos pero identificando altos en malware.")
print("Esto cuantifica amenazas potenciales, guiando priorización en ciberseguridad con visualización clara de distribuciones.")
# Out:
# risk
# ,Bajo     98257
# ,Alto       889
# ,Medio      854
# ,Name: count, dtype: int64
# ,Interpretación: La matriz clasifica riesgos combinando probabilidad e impacto, aquí mostrando predominio de riesgos bajos pero identificando altos en malware.
# ,Esto cuantifica amenazas potenciales, guiando priorización en ciberseguridad con visualización clara de distribuciones.

# %% [markdown]
# ## **🧪 Paso 11: Modelo logístico simple**

# %%
# 6. EDO con Euler: Modelo logístico simple I'(t) = r I (1 - I/K)
def euler_logistic(r=0.1, K=1000, I0=1, t_max=100, h=0.1):
    t = np.arange(0, t_max, h)
    I = np.zeros(len(t))
    I[0] = I0
    for i in range(1, len(t)):
        I[i] = I[i-1] + h * r * I[i-1] * (1 - I[i-1]/K)
    return t, I
t, I = euler_logistic()
plt.figure(figsize=(8, 6))
plt.plot(t, I, color='blue')
plt.title('EDO Logístico con Euler (Crecimiento de Infecciones)')
plt.xlabel('Tiempo')
plt.ylabel('Número de Infecciones')
plt.grid(True)
plt.show()
print("Interpretación: El método de Euler resuelve numéricamente EDO, modelando crecimiento logístico que satura en K, simulando propagación de malware sin retardos.")
print("El gráfico ilustra la curva sigmoide típica, útil para predecir picos de infecciones en escenarios ideales.")
# Out:
# Interpretación: El método de Euler resuelve numéricamente EDO, modelando crecimiento logístico que satura en K, simulando propagación de malware sin retardos.
# ,El gráfico ilustra la curva sigmoide típica, útil para predecir picos de infecciones en escenarios ideales.

# %% [markdown]
# ## **📌 Paso 12: Modelo propagación de malware**

# %%
# 7. EDR con Euler Adaptado (inspirado en Teorema 2.3): I'(t) = r I(t) (1 - I(t)/K) - δ I(t - τ)
# Usamos aproximación discreta (τ = 5, δ=0.05, N=τ/h=50 si h=0.1)
def euler_dde(r=0.1, K=1000, δ=0.05, τ=5, I0=1, t_max=100, h=0.1):
    t = np.arange(0, t_max, h)
    I = np.zeros(len(t))
    delay_steps = int(τ / h)
    for i in range(delay_steps):  # Inicializar con I0
        I[i] = I0
    for i in range(delay_steps, len(t)):
        delay_term = δ * I[i - delay_steps]  # Término retardado
        I[i] = I[i-1] + h * (r * I[i-1] * (1 - I[i-1]/K) - delay_term)
    return t, I
t_dde, I_dde = euler_dde()
plt.figure(figsize=(8, 6))
plt.plot(t_dde, I_dde, color='purple')
plt.title('EDR Logístico con Retardo (Modelando Propagación de Malware con Demora en Detección)')
plt.xlabel('Tiempo')
plt.ylabel('Número de Infecciones')
plt.grid(True)
plt.show()
print("Interpretación: Adaptando Euler a EDR (alineado al Teorema 2.3), incorpora retardos para modelar demoras reales en detección, resultando en oscilaciones o retrasos en el crecimiento.")
print("El gráfico muestra dinámica más realista con fluctuaciones, destacando impactos de retardos en predicciones de brotes de malware.")
# Out:
# Interpretación: Adaptando Euler a EDR (alineado al Teorema 2.3), incorpora retardos para modelar demoras reales en detección, resultando en oscilaciones o retrasos en el crecimiento.
# ,El gráfico muestra dinámica más realista con fluctuaciones, destacando impactos de retardos en predicciones de brotes de malware.

# %%
# Conexión a IA/Clasificación: Usa PCA para features reducidas, entrena un clasificador simple
from sklearn.ensemble import RandomForestClassifier
X_pca = df_pca.drop('classification', axis=1)
y = df_pca['classification']
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.2)  # Split para PCA
clf = RandomForestClassifier()
clf.fit(X_train_pca, y_train)
preds_clf = clf.predict(X_test_pca)
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test, preds_clf)
plt.figure(figsize=(8, 6))
sns.heatmap(pd.crosstab(y_test, preds_clf), annot=True, cmap='Blues', fmt='d')
plt.title('Matriz de Confusión para Clasificador Random Forest en Features PCA')
plt.xlabel('Predicho')
plt.ylabel('Real')
plt.show()
print(f'Accuracy del Clasificador: {acc}')
print("Interpretación: Integrando PCA en un clasificador de IA, logra alta accuracy en detección de malware, conectando todos los métodos previos.")
print("La matriz de confusión visualiza aciertos y errores, validando el enfoque cuantitativo unificado para aplicaciones reales en ciberseguridad.")
# Out:
# Accuracy del Clasificador: 0.99995
# ,Interpretación: Integrando PCA en un clasificador de IA, logra alta accuracy en detección de malware, conectando todos los métodos previos.
# ,La matriz de confusión visualiza aciertos y errores, validando el enfoque cuantitativo unificado para aplicaciones reales en ciberseguridad.

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# > En los tipos de investigación cuantitativa, el teorema soporta aplicaciones prácticas: en PCA, ANOVA + Tukey HSD, y ejemplos como interpolación con matriz de Vandermonde, ajuste de regresión lineal, solución de EDO con Euler, o modelo logístico, al extender estos métodos a EDR. Por instancia, el método de Euler se generaliza directamente al corolario para EDR, permitiendo simulaciones numéricas exactas en escenarios con retardos, como en crecimiento poblacional logístico con demoras en la retroalimentación. Los ejercicios de evaluación —desde Vandermonde hasta PCA y simulaciones cuánticas— se benefician de esta unificación, fomentando una evaluación criteriosa que integra retardos en el análisis.

# %% [markdown]
# <a id="7"></a>
# # 7. Referencias

# %% [markdown]
# <ol> <li>Alvarez-Rodriguez, U., Sanz, M., Lamata, L., & Solano, E. (2017). Advanced-Retarded Differential Equations in Quantum Photonic Systems. Scientific Reports, 7, 42933. <a href="https://doi.org/10.1038/srep42933">https://doi.org/10.1038/srep42933</a></li> <li>Arute, F., Arya, K., Babbush, R., Bacon, D., Bardin, J. C., Barends, R., Biswas, R., Boixo, S., Brandao, F. G. S. L., Buell, D. A., Burkett, B., Chen, Y., Chen, Z., Chiaro, B., Collins, R., Courtney, W., Dunsworth, A., Farhi, E., Foxen, B., … Martinis, J. M. (2019). Quantum supremacy using a programmable superconducting processor. Nature, 574(7779), 505–510. <a href="https://doi.org/10.1038/s41586-019-1666-5">https://doi.org/10.1038/s41586-019-1666-5</a></li> <li>Bharadwaj, S. S., & Sreenivasan, K. R. (2025). Compact quantum algorithms for time-dependent differential equations. Physical Review Research, 7, 023262. <a href="https://doi.org/10.1103/PhysRevResearch.7.023262">https://doi.org/10.1103/PhysRevResearch.7.023262</a></li> <li>Castro, M. Á., Mayorga, C. J., Sirvent, A., & Rodríguez, F. (2020). Exact numerical solutions and high order nonstandard difference schemes for a second order delay differential equation. Mathematical Methods in the Applied Sciences. <a href="https://doi.org/10.1002/mma.9540">https://doi.org/10.1002/mma.9540</a></li> <li>Creswell, J. W. (2014). *Research design: Qualitative, quantitative, and mixed methods approaches* (4th ed.). SAGE Publications.</li> <li>Field, A. (2013). *Discovering statistics using IBM SPSS Statistics* (4th ed.). SAGE Publications.</li> <li>Hill, D. R. C., Antunes, B. A., Cluzel, T., & Mazel, C. (2023). A few words about quantum computing, epistemology, repeatability and reproducibility. HAL Open Science, hal-04089148v1.</li> <li>Hernández Sampieri, R., Fernández Collado, C., & Baptista Lucio, P. (2014). *Metodología de la investigación* (6.ª ed.). McGraw-Hill.</li> <li>Jolliffe, I. T., & Cadima, J. (2016). Principal component analysis: A review and recent developments. *Philosophical Transactions of the Royal Society A: Mathematical, Physical and Engineering Sciences*, *374*(2065), 20150202. <a href="https://doi.org/10.1098/rsta.2015.0202">https://doi.org/10.1098/rsta.2015.0202</a></li> <li>Mayorga, C. J. (2024). Soluciones numéricas exactas y esquemas en diferencias finitas no estándar para ecuaciones diferenciales con retardo. Tesis doctoral, Universidad Nacional Autónoma de México. Recuperado de <a href="https://www.amarun.org/images/amarun/materiales/tesis-doctorales/2024_Mayorga_Carlos.pdf">https://www.amarun.org/images/amarun/materiales/tesis-doctorales/2024_Mayorga_Carlos.pdf</a></li> <li>Mayorga, C. J., Castro, M. Á., Sirvent, A., & Rodríguez, F. (2021). On the Construction of Exact Numerical Schemes for Linear Delay Models. Mathematics, 11(8), 1836. <a href="https://doi.org/10.3390/math11081836">https://doi.org/10.3390/math11081836</a></li> <li>Montgomery, D. C. (2017). *Design and analysis of experiments* (9th ed.). John Wiley & Sons.</li> <li>Nithya, D., Madhusudanan, V., Murthy, B. S. N., Geetha, R., Mung, N. X., Dao, N.-N., & Cho, S. (2024). Delayed dynamics analysis of SEI2RS malware propagation models in cyber–physical systems. Computer Networks, 248, 110481. <a href="https://doi.org/10.1016/j.comnet.2024.110481">https://doi.org/10.1016/j.comnet.2024.110481</a></li> <li>Paudel, H. P., Syamlal, M., Crawford, S. E., Lee, Y.-L., Shugayev, R. A., Lu, P., Ohodnicki, P. R., & Mollot, D. (2022). Quantum Computing and Simulations for Energy Applications: Review and Perspective. ACS Engineering Au, 2(3), 151–196. <a href="https://doi.org/10.1021/acsengineeringau.1c00033">https://doi.org/10.1021/acsengineeringau.1c00033</a></li> <li>Schork, J. (2020). Datasets for PCA (Free CSV Download) | Synthetic & Real Data. Statistics Globe. Recuperado de <a href="https://statisticsglobe.com/datasets-for-pca">https://statisticsglobe.com/datasets-for-pca</a></li> <li>Tukey, J. W. (1977). *Exploratory data analysis*. Addison-Wesley.</li> <li>Tong, Y. (2025). Qubit-Efficient Quantum Algorithm for Linear Differential Equations. arXiv preprint arXiv:2507.16995.</li> <li>Zhang, W., Yang, X., & Yang, L. (2025). A Delayed Malware Propagation Model Under a Distributed Patching Mechanism: Stability Analysis. Mathematics, 13(14), 2266. <a href="https://doi.org/10.3390/math13142266">https://doi.org/10.3390/math13142266</a></li> <li>Zavala, R. J. (2019). Fundamentos epistémicos de la investigación cualitativa y cuantitativa. *Revista Científica de Ciencias de la Salud*, *22*(1), 75–80. <a href="https://www.scielo.org.pe/scielo.php?script=sci_arttext&pid=S2223-25162019000100008">https://www.scielo.org.pe/scielo.php?script=sci_arttext&pid=S2223-25162019000100008</a></li> </ol>
