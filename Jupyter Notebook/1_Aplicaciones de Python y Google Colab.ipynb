# %% [markdown]
# <table style="width: 100%;"> <tr> <td style="width: 60%; align: middle;"> <p style="font-size: 28px; color: #f25625; font-family: Arial; font-weight: bold;"> Curso de Fundamentos de Programación en Python con Google Colab para Ciencia, Datos y Automatización </p> </td> <td style="width: 40%; text-align: center; vertical-align: middle;"> <img width="180" src="data:image/png;base64,..."> </td> </tr> </table>

# %% [markdown]
# <p style="text-align:right; font-weight:bold;">Autor: Carlos Julio Mayorga Arias Ph.D.</p>

# %% [markdown]
# # <center> Aplicaciones de Python en Ciencia, Ingeniería y Datos con Google Colab

# %% [markdown]
# ## Contenido
#
# 1. [Fundamentos de Python](#1)
#    1. [¿Qué es Python?](#1.1)
#    2. [Primeros pasos en Google Colab](#1.2)
#    3. [Comentarios en Python](#1.3)
#    4. [Variables y tipos de datos](#1.4)
#    5. [Operaciones básicas](#1.5)
#    6. [Función `print()` e ingreso de datos con `input()`](#1.6)
#    7. [Conversión de tipos de datos](#1.7)
#    8. [Condicionales: `if`, `elif`, `else`](#1.8)
#    9. [Bucles: `for` y `while`](#1.9)
#    10. [Listas y colecciones](#1.10)
#    11. [Funciones definidas por el usuario](#1.11)
#    12. [Trucos y comandos útiles en Colab](#1.12)
#
# 2. [Manejo de Archivos en Colab](#2)
#    1. [Subir archivos desde tu computadora](#2.1)
#    2. [Leer archivos desde Google Drive](#2.2)
#    3. [Leer archivos CSV con `pandas`](#2.3)
#
# 3. [Librerías Fundamentales para Análisis](#3)
#    1. [`NumPy` - Operaciones numéricas](#3.1)
#    2. [`Pandas` - Manipulación de datos](#3.2)
#    3. [`Matplotlib` y `Seaborn` - Visualización de datos](#3.3)
#    4. [`SymPy` - Matemática simbólica](#3.4)
#    5. [`SciPy` y `Statsmodels` - Estadística](#3.5)
#    6. [`Scikit-learn` - Machine Learning básico](#3.6)
#
# 4. [Análisis Estadístico y Numérico Aplicado](#4)
#    1. [Matriz de Vandermonde](#4.1)
#    2. [Regresión Lineal Simple](#4.2)
#    3. [ANOVA: Análisis de Varianza](#4.3)
#    4. [Prueba de Tukey (post-hoc)](#4.4)
#    5. [PCA: Análisis de Componentes Principales](#4.5)
#    6. [Modelo de Crecimiento Poblacional](#4.6)
#
# 5. [Conceptos Clave y Buenas Prácticas](#5)
#    1. [Diferencia entre `import` y `from ... import`](#5.1)
#    2. [Buenas prácticas de codificación en Python](#5.2)
#    3. [Recursos para seguir aprendiendo Python](#5.3)
#
# 7. [Referencias](#6)

# %% [markdown]
# <a id="1"></a>
# # 1. Fundamentos de Python

# %% [markdown]
# <a id="1.1"></a>
# ## 1.1. ¿Qué es Python?

# %% [markdown]
# Python es un lenguaje de programación de alto nivel, interpretado, y con una sintaxis clara. Es uno de los lenguajes más populares en ciencia, ingeniería y análisis de datos.
#
# **Ventajas:**
# * Fácil de aprender.
# * Gran comunidad.
# * Amplia variedad de librerías.
# * Código legible.

# %%
# Este es un programa en Python
print("Hola, mundo")
# Out:
# Hola, mundo

# %% [markdown]
# <a id="1.2"></a>
# ## 1.2. Primeros pasos en Google Colab

# %% [markdown]
# Google Colab es un entorno gratuito de notebooks en la nube que te permite ejecutar código Python sin instalar nada.
#
# **Características:**
#
# * Basado en Jupyter Notebooks.
# * Ejecuta código en la nube.
# * Permite usar GPU y TPU.
# * Fácil de compartir.

# %%
# Prueba en Colab
print("Estamos trabajando en Google Colab")
# Out:
# Estamos trabajando en Google Colab

# %% [markdown]
# <a id="1.3"></a>
# ## 1.3. Comentarios en Python

# %% [markdown]
# Los comentarios se escriben con `#` y no son ejecutados. Son útiles para documentar el código.

# %%
# Esto es un comentario
print("Este código sí se ejecuta")  # Este es un comentario en línea
# Out:
# Este código sí se ejecuta

# %% [markdown]
# <a id="1.4"></a>
# ## 1.4. Variables y tipos de datos

# %% [markdown]
# En Python, las variables se crean automáticamente al asignarles un valor. No necesitas declarar el tipo.

# %%
x = 10       # entero
y = 3.14     # decimal (float)
nombre = "Ana"  # cadena de texto
activo = True   # booleano

# %% [markdown]
# <a id="1.5"></a>
# ## 1.5. Operaciones básicas

# %% [markdown]
# Python permite operaciones aritméticas simples:

# %%
a = 5
b = 2

print(a + b)  # Suma
print(a - b)  # Resta
print(a * b)  # Multiplicación
print(a / b)  # División
print(a ** b) # Potencia
print(a % b)  # Módulo
# Out:
# 7
# 3
# 10
# 2.5
# 25
# 1

# %% [markdown]
# <a id="1.6"></a>
# ## 1.6. Función `print()` e ingreso de datos con `input()`

# %% [markdown]
# `print()` muestra información, `input()` solicita datos al usuario.

# %%
nombre = input("¿Cuál es tu nombre? ") # Ingreso de string
print("Hola,", nombre)
# Out:
# ¿Cuál es tu nombre?  Carlos Mayorga
# Hola, Carlos Mayorga

# %% [markdown]
# <a id="1.7"></a>
# ## 1.7. Conversión de tipos de datos

# %% [markdown]
# Se utiliza para transformar un tipo de variable a otro.

# %%
edad = input("Edad: ")     # input devuelve str
edad = int(edad)           # Convertir a entero
print(edad + 1)
# Out:
# Edad:  27
# 28

# %% [markdown]
# <a id="1.8"></a>
# ## 1.8. Condicionales: `if`, `elif`, `else`

# %% [markdown]
# Permiten tomar decisiones:

# %%
nota = 85

if nota >= 90:
    print("Excelente")
elif nota >= 70:
    print("Aprobado")
else:
    print("Reprobado")
# Out:
# Aprobado

# %% [markdown]
# <a id="1.9"></a>
# ## 1.9. Bucles: `for` y `while`

# %% [markdown]
# **For:** se usa para repetir un bloque un número de veces.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **While:** se repite mientras una condición sea verdadera.

# %%
x = 0
while x < 5:
    print(x)
    x += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# <a id="1.10"></a>
# ## 1.10. Listas y colecciones

# %% [markdown]
# Las listas almacenan colecciones ordenadas de elementos. Son mutables (se pueden modificar). Se pueden recorrer, agregar o eliminar elementos.

# %%
frutas = ["manzana", "banana", "naranja"]
print(frutas[0])        # Acceder
frutas.append("uva")    # Agregar
print(frutas)
# Out:
# manzana
# ['manzana', 'banana', 'naranja', 'uva']

# %% [markdown]
# <a id="1.11"></a>
# ## 1.11. Funciones definidas por el usuario

# %% [markdown]
# Una función es un bloque de código que realiza una tarea específica y puede ser reutilizado. Las funciones se definen con `def` y pueden recibir argumentos y devolver resultados con `return`.

# %%
def saludar(nombre):
    print("Hola", nombre)

saludar("Carlos")
# Out:
# Hola Carlos

# %% [markdown]
# <a id="1.12"></a>
# ## 1.12. Trucos útiles en Google Colab

# %% [markdown]
# Colab permite ejecutar comandos del sistema con `!`, instalar paquetes con `pip`, y montar Google Drive para guardar o leer archivos. También tiene atajos de teclado útiles.

# %%
# !ls        # Listar archivos del entorno
# !pip install numpy   # Instalar paquetes
from google.colab import drive
drive.mount('/content/drive')  # Montar Google Drive

# %% [markdown]
# <a id=""></a>
# # 2. Manejo de Archivos en Colab

# %% [markdown]
# Puedes subir archivos manualmente o montar Google Drive para leer archivos desde tu nube. Esto es importante cuando trabajas con bases de datos `(.csv, .xlsx, .txt)`.

# %% [markdown]
# <a id="2.1"></a>
# ## 2.1. Subir archivos desde tu computadora

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# <a id="2.2"></a>
# ## 2.2. Leer archivos desde Google Drive

# %%
import pandas as pd
df = pd.read_csv('archivo.csv')
df.head()

# %% [markdown]
# <a id="2.3"></a>
# ## 2.3. Leer archivos CSV con `pandas`

# %%
import pandas as pd
df = pd.read_csv('archivo.csv')
df.head()

# %% [markdown]
# <a id="3"></a>
# # 3. Librerías Fundamentales para Análisis

# %% [markdown]
# Las librerías son colecciones de funciones listas para usar. Ejemplos:
#
# * `NumPy`: Cálculo numérico y matrices
# * `Pandas`: Análisis de datos
# * `Matplotlib / Seaborn`: Gráficos
# * `SymPy`: Matemática simbólica
# * `SciPy / statsmodels`: Estadística
# * `sklearn`: Machine Learning

# %% [markdown]
# <a id="3.1"></a>
# ## 3.1. `NumPy` - Operaciones numéricas

# %%
import numpy as np
a = np.array([1, 2, 3])
print(np.mean(a))
# Out:
# 2.0

# %% [markdown]
# <a id="3.2"></a>
# ## 3.2. `Pandas` - Manipulación de datos

# %%
import pandas as pd
df = pd.DataFrame({'a': [1, 2], 'b': [3, 4]})
print(df.describe())
# Out:
#               a         b
# count  2.000000  2.000000
# mean   1.500000  3.500000
# std    0.707107  0.707107
# min    1.000000  3.000000
# 25%    1.250000  3.250000
# 50%    1.500000  3.500000
# 75%    1.750000  3.750000
# max    2.000000  4.000000

# %% [markdown]
# <a id="3.3"></a>
# ## 3.3. `Matplotlib` y `Seaborn` - Visualización de datos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.histplot([1,2,2,3,3,3])
plt.show()

# %% [markdown]
# <a id="3.4"></a>
# ## 3.4. `SymPy` - Matemática simbólica

# %%
from sympy import symbols, Eq, solve

x = symbols('x')
eq = Eq(x**2 - 4, 0)
sol = solve(eq)
print(sol)
# Out:
# [-2, 2]

# %% [markdown]
# <a id="3.5"></a>
# ## 3.5. `SciPy` y `Statsmodels` - Estadística

# %%
from scipy import stats

data = [2, 3, 3, 4, 4, 4, 5]
print(stats.ttest_1samp(data, 3))
# Out:
# TtestResult(statistic=np.float64(1.5491933384829673), pvalue=np.float64(0.17230829673039985), df=np.int32(6))

# %% [markdown]
# <a id="3.6"></a>
# ## 3.6. `Scikit-learn` - Machine Learning básico

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array([[1], [2], [3]])
y = np.array([2, 4, 6])

model = LinearRegression()
model.fit(X, y)
print(model.coef_)
# Out:
# [2.]

# %% [markdown]
# <a id="4"></a>
# # 4. Análisis Estadístico y Numérico Aplicado

# %% [markdown]
# <a id="4.1"></a>
# ## 4.1. Matriz de Vandermonde

# %% [markdown]
# Es una matriz usada en álgebra y polinomios. Se usa comúnmente para ajustar modelos polinómicos o resolver sistemas de ecuaciones con polinomios.

# %%
import numpy as np
x = np.array([1, 2, 3])
vander = np.vander(x, increasing=True)
print(vander)
# Out:
# [[1 1 1]
#  [1 2 4]
#  [1 3 9]]

# %% [markdown]
# <a id="4.2"></a>
# ## 4.2. Regresión Lineal Simple

# %% [markdown]
# Relaciona dos variables con una línea recta.

# %%
from sklearn.linear_model import LinearRegression

X = np.array([[1], [2], [3]])
y = np.array([2, 4, 5])

model = LinearRegression()
model.fit(X, y)
print(model.coef_, model.intercept_)
# Out:
# [1.5] 0.666666666666667

# %% [markdown]
# <a id="4.3"></a>
# ## 4.3. ANOVA: Análisis de Varianza

# %% [markdown]
# Compara medias entre 3 o más grupos.

# %%
import scipy.stats as stats

grupo1 = [4,5,6]
grupo2 = [5,6,7]
grupo3 = [8,9,10]

f, p = stats.f_oneway(grupo1, grupo2, grupo3)
print("p-value:", p)
# Out:
# p-value: 0.006591796875

# %% [markdown]
# <a id="4.4"></a>
# ## 4.4. Prueba de Tukey (post-hoc)

# %% [markdown]
# Se aplica luego de una ANOVA cuando hay diferencias significativas, para saber entre qué grupos existen esas diferencias.

# %%
import pandas as pd
from statsmodels.stats.multicomp import pairwise_tukeyhsd

df = pd.DataFrame({
    'valor': [5,6,7,5,6,7,8,9,10],
    'grupo': ['A']*3 + ['B']*3 + ['C']*3
})

tukey = pairwise_tukeyhsd(endog=df['valor'], groups=df['grupo'], alpha=0.05)
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      A      B      0.0    1.0 -2.5052 2.5052  False
#      A      C      3.0 0.0242  0.4948 5.5052   True
#      B      C      3.0 0.0242  0.4948 5.5052   True
# ---------------------------------------------------

# %% [markdown]
# <a id="4.5"></a>
# ## 4.5. PCA: Análisis de Componentes Principales

# %% [markdown]
# Es una técnica para reducir la cantidad de variables en un conjunto de datos, transformándolas en nuevas variables llamadas componentes principales, que conservan la mayor varianza posible.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X = np.array([[1,2], [3,4], [5,6]])
X_scaled = StandardScaler().fit_transform(X)

pca = PCA(n_components=1)
X_pca = pca.fit_transform(X_scaled)
print(X_pca)
# Out:
# [[-1.73205081]
#  [ 0.        ]
#  [ 1.73205081]]

# %% [markdown]
# <a id="4.6"></a>
# ## 4.6. Modelo de Crecimiento Poblacional

# %% [markdown]
# Es un modelo exponencial que representa cómo una población crece con el tiempo según una tasa constante. Se aplica también en economía, epidemiología, etc.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 10, 100)
P0 = 100
r = 0.3
P = P0 * np.exp(r * t)

plt.plot(t, P)
plt.title("Crecimiento poblacional")
plt.xlabel("Tiempo")
plt.ylabel("Población")
plt.show()

# %% [markdown]
# <a id="5"></a>
# # 5. Conceptos Clave y Buenas Prácticas

# %% [markdown]
# <a id="5.1"></a>
# ## 5.1. Diferencia entre `import` y `from ... import`

# %% [markdown]
# `import`
#
# Carga todo el módulo, y para usar sus funciones debes anteponer el nombre del módulo.

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %% [markdown]
# `from ... import`
#
# Importa solo una parte específica del módulo, lo que te permite usarla directamente.

# %%
from math import sqrt
print(sqrt(25))
# Out:
# 5.0

# %% [markdown]
# <a id="5.2"></a>
# ## 5.2. Buenas prácticas de codificación en Python

# %% [markdown]
# * ✅ Usa nombres descriptivos para tus variables y funciones.
# * ✅ Comenta tu código de forma clara.
# * ✅ Mantén indentación coherente (4 espacios por nivel).
# * ✅ No repitas código (principio DRY: Don’t Repeat Yourself).
# * ✅ Usa funciones para organizar tareas repetitivas.
# * ✅ Aplica convenciones de estilo PEP8 (estilo oficial de Python).
# * ✅ Usa entornos virtuales si trabajas fuera de Colab.
# * ✅ Guarda tus notebooks en Drive o GitHub para no perder avances.

# %%
# ❌ Malo
a = 3.1416 * r * r

# ✅ Bueno
pi = 3.1416
radio = 2
area_circulo = pi * radio ** 2

# %% [markdown]
# <a id="5.3"></a>
# ## 5.3. Recursos para seguir aprendiendo Python

# %% [markdown]
# * [Python.org - Documentación oficial](https://docs.python.org/3/)
# * [W3Schools - Curso interactivo de Python](https://www.w3schools.com/python/)
# * [Real Python - Artículos y tutoriales](https://realpython.com/)
# * [Kaggle - Notebooks y datasets de ciencia de datos](https://www.kaggle.com/)
# * [Google Colab - Cuadernos interactivos en la nube](https://colab.research.google.com/)
# * [Automate the Boring Stuff with Python - Libro gratuito](https://automatetheboringstuff.com/)

# %% [markdown]
# <a id="6"></a>
# # 6. Referencias

# %% [markdown]
# 1. McKinney, W. (2018). Python for Data Analysis: Data Wrangling with Pandas,NumPy, and IPython (2nd ed.). O’Reilly Media.
# 2. Oliphant, T. E. (2015). A Guide to NumPy (2nd ed.). USA: Continuum Analytics.
# 3. Raschka, S., & Mirjalili, V. (2019). Python Machine Learning (3rd ed.). Packt Publishing.
# 4. Sweigart, A. (2015). Automate the Boring Stuff with Python: Practical Programming for Total Beginners. No Starch Press.
# 5. VanderPlas, J. (2016). Python Data Science Handbook: Essential Tools for Working with Data. O’Reilly Media.
# 6. Virtanen, P., Gommers, R., Oliphant, T. E., Haberland, M., Reddy, T., Cournapeau, D., ... & SciPy Contributors. (2020). SciPy 1.0: Fundamental Algorithms for Scientific Computing in Python. Nature Methods, 17(3), 261–272. https://doi.org/10.1038/s41592-019-0686-2
